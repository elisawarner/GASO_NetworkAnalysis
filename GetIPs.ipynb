# %%
import pandas as pd
import re
import os
import numpy as np

# %%
scamSites = pd.read_csv("ScamWebsites.csv")
scamSites.shape
# Out:
# (2075, 27)

# %%
# print header
list(scamSites)
# Out:
# ['Requested domain',
#  'API response',
#  'Domain name',
#  'Domain extension',
#  'Trust score',
#  'IP address',
#  'IP country',
#  'ISP name',
#  'WHOIS creation date',
#  'Registrar name',
#  'Registrar IANA code',
#  'Registrant name',
#  'Registrant company',
#  'Registrant email',
#  'Registrant country',
#  'Agv. review score',
#  'Total reviews',
#  'Total Facebook comments',
#  'Total Scamadviser votes',
#  'Request HTTP status',
#  'Tags',
#  'Keywords',
#  'Trust rules',
#  'Alexa rank',
#  'Pageviews',
#  'Created at',
#  'Updated at']

# %%
def PingSite(siteName):

    strippedName = re.findall('[a-z0-9.-]+',name)
    dotCount = [x.count('.') for x in strippedName]

    strippedName = strippedName[np.argmax(dotCount)]

    #print(strippedName)
    command = 'nslookup %s' % (strippedName)
    x = os.popen(command).read().split('\n')
    
    if len(x) >= 7:
        print(strippedName, "...SUCCESS")
    else:
        print(strippedName, "...FAIL")
    
    return x

# %%
def ScrapeLookup(nslookupOutput):
    webInfoJSON = {}
    lookupThemes = ["Name","Address","Alias"]
    
    if len(nslookupOutput) < 7:
        return 0
    else:
        currentTheme = ""
        for i in range(len(nslookupOutput)):
            # check if we need to update currentTheme
            if nslookupOutput[i] == '':
                continue

            for theme in lookupThemes:
                if nslookupOutput[i].startswith(theme):
                    currentTheme = theme
                    webInfoJSON[currentTheme] = []
                    stripped = re.findall('(?<=:)\s+.+',nslookupOutput[i])[0].strip('\t ')
            
            if currentTheme and stripped == "": # we have a theme, but we're not on theme line
                stripped = nslookupOutput[i].strip('\t ')

            if currentTheme:
                webInfoJSON[currentTheme].append(stripped)
                stripped = "" # redefine to clear
    
    return webInfoJSON

# %%
# Create a DF with Names, Addresses, and Aliases
df = pd.DataFrame(columns={'Domain','Name','Address','Alias'})

for name in scamSites['Requested domain']:
    pingOutput = PingSite(name)
    outputDict = ScrapeLookup(pingOutput)
    
    if outputDict:
        outputDict['Domain'] = name
        outputDict['Address'].sort()
        df = df.append(outputDict, ignore_index=True)
# Out:
# mgmmacau.live ...SUCCESS
# larcla.live ...SUCCESS
# down.a51fan.com ...SUCCESS
# down.a51fan.com ...SUCCESS
# app.kkyyipa.com ...SUCCESS
# down.a51fan.com ...SUCCESS
# sjpplcplus.com ...FAIL
# btcturocenter.com ...SUCCESS
# etradest.xyz ...SUCCESS
# bbtc.gold ...SUCCESS
# www.bittrex168.com ...SUCCESS
# www.fengdongjz.com ...SUCCESS
# www.passiveoutcomes.com ...SUCCESS
# commercepart-time.com ...SUCCESS
# www.mlit.top ...SUCCESS
# trader.eightprime-fx.com ...SUCCESS
# hublogs.com ...SUCCESS
# wnsramq.com ...FAIL
# ahh344.com ...FAIL
# www.longchen18.com ...SUCCESS
# btcflashchain.uk ...SUCCESS
# veritexfrost.com ...SUCCESS
# h5.coinapm.com ...SUCCESS
# app.conceptseries.live ...SUCCESS
# mitsui55.com ...SUCCESS
# w.shouhuo076.com ...FAIL
# www.facoin.co ...FAIL
# www.sunrayforex.com ...SUCCESS
# facoinplus.com ...SUCCESS
# www.ohmeho.com ...SUCCESS
# wedatetw.com ...FAIL
# idstw666.xyz ...SUCCESS
# www.russell4m.com ...SUCCESS
# www.jolover.com ...SUCCESS
# www.highlevel4dc.com ...SUCCESS
# www.clk2btc.com ...SUCCESS
# www.newgoodcoin.com ...SUCCESS
# app.tbg.tw ...SUCCESS
# pymz.cn ...SUCCESS
# pymz.cn ...SUCCESS
# pymz.cn ...SUCCESS
# mrt.bet ...SUCCESS
# member.brokerinvestment.com ...SUCCESS
# www.sunnyforex.com ...SUCCESS
# www.hun-fx.com ...FAIL
# www.rzdhdu.com ...FAIL
# web.spp655.com ...SUCCESS
# web.herm95.com ...SUCCESS
# web.euronext.cc ...SUCCESS
# tk.k-coin.net ...SUCCESS
# sjpplcs.com ...FAIL
# jkk777.com ...SUCCESS
# www.beann.net ...SUCCESS
# taobao818888.com ...SUCCESS
# yibts.com ...SUCCESS
# hengyun1688.website ...SUCCESS
# sharetron.fund ...SUCCESS
# bexfinance.ltd ...SUCCESS
# 24onlineforexpips.com ...SUCCESS
# coinnex-capital.com ...FAIL
# connaughtfx.com ...SUCCESS
# xcrypto-profit.com ...FAIL
# goldbrick.ltd ...FAIL
# bitcomex.biz ...FAIL
# ag98.com ...SUCCESS
# www.surecake688.com ...SUCCESS
# coinskale.com ...FAIL
# www.suntonfx.club ...SUCCESS
# www.suntonfx.site ...SUCCESS
# www.suntonfx.world ...SUCCESS
# www.suntonfx.asia ...SUCCESS
# www.jumperfx.xyz ...FAIL
# 24invest.co ...FAIL
# cryptooinvestment.com ...SUCCESS
# otakucoin.io ...SUCCESS
# ceo-eth.com ...SUCCESS
# xdgmining.com ...SUCCESS
# www.sandwindfx.store ...SUCCESS
# larcmac.online ...FAIL
# bitcoinexperts.ltd ...FAIL
# www.thefutureguard.com ...SUCCESS
# www.pionex.com ...SUCCESS
# www.bitoexs.com ...FAIL
# www.diamond-tt.com ...SUCCESS
# www.diamonds-tt.com ...SUCCESS
# www.rixin-inv.com ...SUCCESS
# m.okcoinmarket.com ...FAIL
# app.filpool.store ...SUCCESS
# www.rexxglobal.com ...SUCCESS
# www.hongkong-online-fraud-asset-tracing.com ...SUCCESS
# m.centerassets.com ...SUCCESS
# vip.xinaocl.xyz ...FAIL
# www.menrm.com ...SUCCESS
# hi.com ...SUCCESS
# www.bobty203.com ...SUCCESS
# dbty006.com ...SUCCESS
# dbty007.com ...SUCCESS
# h5.coinbaseproac.com ...SUCCESS
# h5.koorbitk.com ...FAIL
# wap.hotbit66.xyz ...FAIL
# wap.ba1762.com ...SUCCESS
# wap.yibits.cc ...SUCCESS
# www.goldmans.online ...SUCCESS
# user4.vipotor.com ...SUCCESS
# m.walletput.com ...SUCCESS
# velocity.hkexnews.club ...FAIL
# m.vcex.io ...SUCCESS
# www.god55win.com ...SUCCESS
# kale.com ...SUCCESS
# www.protrade.cc ...SUCCESS
# www.tradingview.com ...SUCCESS
# staywealthyroad.com ...SUCCESS
# www.poloniex-pro.vip ...SUCCESS
# df.imzfqzq.cn ...SUCCESS
# 706viw.btex11.com ...SUCCESS
# pcicoin.com ...SUCCESS
# web.antsex.com ...SUCCESS
# trader.cjcmarketsglobal.com ...SUCCESS
# bitfinger.net ...SUCCESS
# download.sleon.cn ...SUCCESS
# coinskyex4.1.9.4.27.apk ...FAIL
# getbitapp.oss-cn-hongkong.aliyuncs.com ...SUCCESS
# getbitapp.oss-cn-hongkong.aliyuncs.com ...SUCCESS
# getbitapp.oss-cn-hongkong.aliyuncs.com ...SUCCESS
# www.tradcoins.com ...SUCCESS
# sjf-fx.com ...FAIL
# www.qpbapp.com ...SUCCESS
# tolikeweb.com ...FAIL
# www.coins.energy ...SUCCESS
# likecz.cc ...SUCCESS
# bkccoin.com ...SUCCESS
# user1.rosyglobal.com ...FAIL
# m.dobit.cc ...SUCCESS
# glluckfx.cc ...SUCCESS
# www.ysbx-ap.com ...SUCCESS
# os.666.congfeng.cn ...SUCCESS
# napmine.com ...SUCCESS
# apsweb.2gclk2.cn ...FAIL
# www.re-markets.com ...FAIL
# app.bwteo.cn ...FAIL
# user4.rosystyle.com ...FAIL
# www.bitbank.com ...SUCCESS
# app.convoyfund.com ...SUCCESS
# www.trxcloud.cc ...SUCCESS
# fvgu.xyz ...SUCCESS
# jdes.xyz ...SUCCESS
# cd29.xyz ...SUCCESS
# www.flash68.com ...SUCCESS
# www.flash68.com ...SUCCESS
# bmex.plus ...SUCCESS
# portal.tmgm-gc.com ...SUCCESS
# zprgzk.cn ...SUCCESS
# portal.tmgm.com ...SUCCESS
# allwin.sandwindfx.com ...SUCCESS
# goodsts.com ...FAIL
# m.pangaea-global.com ...SUCCESS
# mexico-forex.com ...SUCCESS
# prize.covaxorg.net ...FAIL
# www.zags.tw ...SUCCESS
# zhm.bee1314.com ...SUCCESS
# o.oneofu.work ...SUCCESS
# gm.gmo-click.xyz ...SUCCESS
# fxbritt.com ...SUCCESS
# www.kin1668.com ...SUCCESS
# mianqian.wb5zv7.cn ...SUCCESS
# a.mugame.tw ...SUCCESS
# a.mugames.tw ...SUCCESS
# m.sbivct.com ...SUCCESS
# sunacfx.com ...FAIL
# www.ring-forex.com ...SUCCESS
# www.doublecoin.com.tw ...SUCCESS
# fbmall.newgangyun.com ...SUCCESS
# www.sgsun.io ...SUCCESS
# www.ssgsun.com ...SUCCESS
# m.coinbox.one ...FAIL
# ob9w5g.flxum.xyz ...SUCCESS
# h2es65.gdcsettle88.xyz ...SUCCESS
# 4k6dfg.6777k.xyz ...SUCCESS
# x0gmgm.grofen8.com ...SUCCESS
# m.xdtx11.xyz ...SUCCESS
# 90suls.6777k.xyz ...SUCCESS
# www.costpayin.com ...SUCCESS
# web.arranos.com ...SUCCESS
# apple.ntbgy.com ...SUCCESS
# www.nzbtc.top ...SUCCESS
# crazyorlove.com ...FAIL
# account.willfxvip.com ...SUCCESS
# account.xjpszjr.net ...SUCCESS
# oi7s.xyz ...FAIL
# m.bitsite.net ...SUCCESS
# ferlove.com ...SUCCESS
# www.maxpfx.com ...FAIL
# amendaex.com ...SUCCESS
# u-trade.com ...SUCCESS
# pkex-app.xyz ...SUCCESS
# cg2021.xyz ...SUCCESS
# rf25.xyz ...SUCCESS
# wqse.xyz ...SUCCESS
# ke29.xyz ...SUCCESS
# nuvv.xyz ...SUCCESS
# lswx.xyz ...SUCCESS
# ersx.xyz ...SUCCESS
# ooun.xyz ...SUCCESS
# uism.xyz ...FAIL
# es78.xyz ...FAIL
# ws35.xyz ...SUCCESS
# poww.xyz ...SUCCESS
# swvn.xyz ...SUCCESS
# www.nico.exchange ...FAIL
# uoccda.com ...SUCCESS
# app.tmx68.com ...SUCCESS
# apkoss.oss-cn-chengdu.aliyuncs.com ...SUCCESS
# elitefxinvestment.live ...SUCCESS
# www.gou1788.com ...FAIL
# www.usbanking.net ...SUCCESS
# h5.opticaobo.top ...SUCCESS
# czw1907.supergamingco.com ...SUCCESS
# vdoge.net ...SUCCESS
# www.coinprobinary.com ...FAIL
# www.coinprobinary.com ...FAIL
# www.cfa165.com ...FAIL
# download.bitfinex963.com ...SUCCESS
# www.anandforex.com ...FAIL
# avatradetwai.com ...SUCCESS
# www.fit3650.com ...SUCCESS
# dtnet3650.com ...SUCCESS
# www.effortwe365.com ...FAIL
# www.effortwe360.com ...FAIL
# www.vforex3650.com ...SUCCESS
# a1s2d1a231z.xyz ...SUCCESS
# m.mgjt2008.top ...SUCCESS
# www.zbg.com ...SUCCESS
# www.iujshg.top ...SUCCESS
# m.baliren5566.com ...SUCCESS
# cmmcisecurities.com ...FAIL
# www.inpcmarket.com ...SUCCESS
# h5.square999.net ...SUCCESS
# h5.square99.xyz ...FAIL
# www.esgexvip.com ...FAIL
# www.binettex.com ...FAIL
# 365s444.com ...SUCCESS
# h5.m7921gsgda12.xyz ...SUCCESS
# h5.mas9dhcbhasfweb.xyz ...SUCCESS
# uificforex.com ...SUCCESS
# crm.forex1800.com ...SUCCESS
# www.steady168.com ...SUCCESS
# steady3650.com ...SUCCESS
# steady168.com ...SUCCESS
# m.xpj66589.com ...SUCCESS
# jp-morgan.etb.org.cn ...SUCCESS
# byteglobals.com ...FAIL
# login.lexin.me ...SUCCESS
# www.hongji.xin ...SUCCESS
# zfrrz.com ...SUCCESS
# zjnet.top ...SUCCESS
# dbgmarketw.com ...SUCCESS
# etxcapitaltw.com ...SUCCESS
# dbgmarke886.com ...SUCCESS
# www.globedx2.com ...SUCCESS
# 2823amjs.com ...SUCCESS
# www.jsjrforextw.com ...SUCCESS
# f00b204e9800998ecf8427e.gkfx61.vip ...SUCCESS
# brickmex.com ...SUCCESS
# river.mcpcu.com ...SUCCESS
# rr.ls-bit.com ...SUCCESS
# fog-eefx.net ...SUCCESS
# yashengforex.com ...SUCCESS
# www.twdcep.com ...FAIL
# wss.mieasier.xyz ...SUCCESS
# btcaadd.com ...SUCCESS
# www.bizzan.vip ...FAIL
# newebtc.co ...FAIL
# coinsn.club ...SUCCESS
# down.htlovelby.com ...SUCCESS
# ezbuy888.com ...SUCCESS
# web.gsm166.com ...SUCCESS
# win33.net ...FAIL
# bagmiomio.com ...SUCCESS
# shopvmp.com ...SUCCESS
# www.oub90.com ...SUCCESS
# www.hbet132.com ...SUCCESS
# blockbook-bitcoin.tronwallet.me ...SUCCESS
# www.qisex.com ...SUCCESS
# www.luckycoin.shop ...SUCCESS
# igmarke.com ...SUCCESS
# www.leta.ink ...SUCCESS
# www.exblkpro.com ...SUCCESS
# www.gndownload.com ...SUCCESS
# www.uh-und.com ...SUCCESS
# www.bitlbxpro.com ...SUCCESS
# www.potex.org ...FAIL
# www.gndownload.com ...SUCCESS
# wclubpro.com ...SUCCESS
# www.gndownload.com ...SUCCESS
# luckycoin.shop ...SUCCESS
# ryderexchange.site ...SUCCESS
# www.heydayint.com ...SUCCESS
# www.leobor.com ...SUCCESS
# www.financial-agent.com ...FAIL
# www.xndownload.com ...SUCCESS
# www.xndownload.com ...SUCCESS
# dsfx99.com ...FAIL
# www.a3gamesbar.net ...SUCCESS
# www.potmax.org ...FAIL
# www.rockfort-markets.com ...SUCCESS
# www.ryderexchange.site ...SUCCESS
# ali.6783322.com ...FAIL
# www.xndownload.com ...SUCCESS
# www.xndownload.com ...SUCCESS
# cp-financial.com ...SUCCESS
# loit741.com ...SUCCESS
# www.ng3999.com ...SUCCESS
# dso-fx.com ...SUCCESS
# www.bitvnex.com ...SUCCESS
# www.pkexce.com ...FAIL
# wap.coinbene.shop ...SUCCESS
# loveinworld.com ...FAIL
# etherconnect.co ...FAIL
# mcpexchange.com ...SUCCESS
# www.hzforyou.com ...SUCCESS
# www.cobo666.com ...FAIL
# www.jinzhuzhuan.com ...FAIL
# www.ubn4234.live ...FAIL
# gkjk2021.com ...FAIL
# www.ghiueyiueyhriue.live ...SUCCESS
# www.hjhdcv.life ...SUCCESS
# www.u8581321.live ...FAIL
# www.qqkkx.com ...SUCCESS
# www.hjkdhfkj.xyz ...SUCCESS
# www.descoin.live ...SUCCESS
# www.tmxgroup.live ...SUCCESS
# www.coincusp.vip ...SUCCESS
# www.tkbtc1.com ...SUCCESS
# www.pishbbaxc.live ...SUCCESS
# www.jkhiurthrkjhfg.space ...SUCCESS
# www.554xgah.live ...SUCCESS
# www.876hbba67.live ...SUCCESS
# www.ytyetrfjhdgc.xyz ...SUCCESS
# www.piihbhsa.live ...SUCCESS
# www.o17bvabs.xyz ...SUCCESS
# www.kjerkjef.club ...SUCCESS
# www.t0988123.club ...FAIL
# www.bihuiglobal.com ...SUCCESS
# www.bitcn.live ...SUCCESS
# www.bikipro88.xyz ...SUCCESS
# www.guyegfuyh.live ...SUCCESS
# www.m87aybsadweb.xyz ...FAIL
# www.t9jcnas.club ...FAIL
# www.ji88sax.xyz ...SUCCESS
# www.m71263h12.online ...SUCCESS
# www.missionp.app ...SUCCESS
# www.xntd123.com ...FAIL
# www.t88hjasd.xyz ...SUCCESS
# www.jkfjgkfjgkfj.life ...SUCCESS
# www.ls-bit.com ...SUCCESS
# www.ciex.io ...SUCCESS
# btcoinss.com ...SUCCESS
# www.yyzrkf.com ...FAIL
# pearcoin.net ...SUCCESS
# capitalplus.uk ...SUCCESS
# spglob.com ...FAIL
# sjpplcme.com ...FAIL
# down.bjliancheng.cn ...SUCCESS
# cash3.otcsec.com ...SUCCESS
# hk-exnews.com ...SUCCESS
# mallhelper.org ...SUCCESS
# m.uappdown.com ...SUCCESS
# app.jinchuan.tw ...SUCCESS
# ryh.yewjua066.xyz ...SUCCESS
# garenadigital.vip ...SUCCESS
# garenadigital.cc ...SUCCESS
# h5.blk233.com ...SUCCESS
# h5.kbug11.xyz ...SUCCESS
# h5.korblt.com ...SUCCESS
# www.char2base.xyz ...SUCCESS
# select-limited.com ...FAIL
# treasure-reef-limited.com ...SUCCESS
# treasure-reef.com ...FAIL
# sgcgroupltd.com ...SUCCESS
# facebookbit1.com ...SUCCESS
# h5.borsaint.com ...FAIL
# www.igtrade.top ...SUCCESS
# hkyyexe.com ...SUCCESS
# crown.fudingking.com ...SUCCESS
# www.eazycomeing13.com ...SUCCESS
# www.kpcb77.com ...SUCCESS
# m.700823.com ...SUCCESS
# hklot.hk.cn ...SUCCESS
# 1999.cc ...SUCCESS
# m.gzpzhi888.com ...FAIL
# tw.worldfistw.xyz ...FAIL
# www.merrillfortw.cc ...FAIL
# www.imerrtw.top ...FAIL
# www.imerrtw.com ...SUCCESS
# www.ssz7300.com ...FAIL
# www.txfq188.com ...SUCCESS
# dcggroup.mystrikingly.com ...SUCCESS
# apps.apple.com ...SUCCESS
# apps.apple.com ...SUCCESS
# etf.qiyangin.com ...SUCCESS
# bo.qiyangin.com ...SUCCESS
# www.aimc.co ...FAIL
# www.huangdingfx.com ...SUCCESS
# www.zhixin.at ...SUCCESS
# www.phhshopify.com ...SUCCESS
# linkhuminvestment.com ...SUCCESS
# net.coinfu2020.com ...SUCCESS
# simriches.com ...SUCCESS
# sandboxbit.com ...SUCCESS
# www.rely-asia.com ...SUCCESS
# www.jindaojy.com ...FAIL
# www.rsmbit.com ...FAIL
# acelitemds.com ...FAIL
# www.odjvdo.com ...SUCCESS
# bullsphere.com ...FAIL
# am.ls-bit.com ...SUCCESS
# kiauddh78mucn.com ...SUCCESS
# liashen.com ...FAIL
# fxcccenter.com ...SUCCESS
# cmegrouptop.com ...SUCCESS
# etsuhdttop.com ...SUCCESS
# fxcmtop.com ...SUCCESS
# blockinmax.com ...SUCCESS
# acxtop.com ...SUCCESS
# blockinb2c.com ...SUCCESS
# lbankbroker.com ...SUCCESS
# cmegroupbox.com ...SUCCESS
# bitchembox.com ...SUCCESS
# bitchempro.com ...SUCCESS
# etsuhdtbroker.com ...SUCCESS
# gkfx.ytzbaiw.cn ...SUCCESS
# gkfx.jmwmvvc.cn ...SUCCESS
# a.hkhuifa.com ...SUCCESS
# jettd.cn ...SUCCESS
# h5.bblsint.com ...SUCCESS
# h5.coinbaseprolay.com ...SUCCESS
# h5.msjaut.com ...SUCCESS
# h5.internationalue.com ...SUCCESS
# h5.hifly37823.top ...SUCCESS
# h5.fhjtax.com ...SUCCESS
# c3e.89650.top ...SUCCESS
# www.costerexchange.com ...SUCCESS
# www.yafit.site ...SUCCESS
# www.tarakava.com ...SUCCESS
# www.purelyfx2015.com ...SUCCESS
# www.skyfx.tw ...SUCCESS
# ftxjys.com ...SUCCESS
# www.tradesynthetic.com ...SUCCESS
# bitcomex.pw ...SUCCESS
# pureinvest.ltd ...FAIL
# miners-gain.co ...FAIL
# alpha-global.ltd ...SUCCESS
# credminer.cc ...FAIL
# primemerit.ltd ...SUCCESS
# twmanagement.ltd ...FAIL
# www.bestresolute.com ...SUCCESS
# coinglobal.ltd ...FAIL
# prudentcapital.ltd ...FAIL
# acrylic-trade.com ...SUCCESS
# www.coinportal.ltd ...FAIL
# coinstop.ltd ...SUCCESS
# ceibafinance.co ...FAIL
# kryptosminer.com ...FAIL
# www.philippinesstock.com ...SUCCESS
# topbitsoption.com ...FAIL
# paywaysfinance.com ...SUCCESS
# bitcoin-franchise.ltd ...FAIL
# bitcoin-franchise.ltd ...FAIL
# stanbicfinanceltd.com ...SUCCESS
# ng1117.com ...SUCCESS
# pollytradecapital.com ...FAIL
# veluxcorporationlimited.com ...SUCCESS
# access-traders.world ...SUCCESS
# cryptosignal95.com ...FAIL
# pimcoasialimited.brocktw.com ...SUCCESS
# www.cryptocurrencycoinminers.com ...SUCCESS
# inetworkcctv.com ...SUCCESS
# yuetoskwnqjs.com ...SUCCESS
# kiusyhfbgbs368.com ...SUCCESS
# sdfdlkfsd.com ...SUCCESS
# nudwislcjfehxs.com ...SUCCESS
# ryeusgdcfcsefl2.com ...SUCCESS
# yuwsiawojxakqxnsj.com ...SUCCESS
# moxiaifnslsoejsa.com ...SUCCESS
# grdwd5.com ...SUCCESS
# sfjnfasodsmf.com ...SUCCESS
# www.focp.net ...SUCCESS
# wuqhaunfs.com ...SUCCESS
# skdifjcge.com ...SUCCESS
# okbitb.com ...FAIL
# zeonic.cc ...SUCCESS
# www.kryptoxminer.com ...SUCCESS
# future-traders.ltd ...FAIL
# cryptotrade-fxinternational.com ...SUCCESS
# www.jiasheng138.com ...FAIL
# fxcm.muanlife123.com ...SUCCESS
# patyners.com ...SUCCESS
# m.y69988.com ...SUCCESS
# aomego.com ...SUCCESS
# inpcforex.com ...FAIL
# btcwold.com ...FAIL
# bustfx.com ...SUCCESS
# rifagala.com ...SUCCESS
# zxkj.gp866.cn ...SUCCESS
# www.bggcoins.com ...SUCCESS
# independencefinancialbank.com ...SUCCESS
# www.xtbinvest.com ...SUCCESS
# bavariamarkets.com ...SUCCESS
# surecoininvestors.com ...SUCCESS
# udzd6x.crctrusttw.com ...SUCCESS
# coinxpress.net ...SUCCESS
# coininner.top ...SUCCESS
# east-century.info ...SUCCESS
# amyh.hecaism.cn ...SUCCESS
# www.chiusin.com ...SUCCESS
# www.tronfarm.me ...SUCCESS
# fubon.net ...SUCCESS
# yas168168.com ...SUCCESS
# www.coinplace.pro ...SUCCESS
# c.f182.cn ...SUCCESS
# c.js009.cn ...SUCCESS
# mex.bitfinexp.com ...SUCCESS
# xn--8prs50h.xn--fiqs8s ...SUCCESS
# credit.ytfff.space ...FAIL
# www.jscoptyltd.com ...SUCCESS
# www.hengryfx.net ...FAIL
# www.hengry-fx.com ...SUCCESS
# www.jiama1666now.com ...SUCCESS
# www.wtiltd-hk.com ...SUCCESS
# www.gaojugonsi8.com ...SUCCESS
# www.liferich1356.com ...SUCCESS
# www.tslonlineclass.com ...SUCCESS
# www.winmaxfx.co ...FAIL
# www.must-win.net ...SUCCESS
# app.dx986.cn ...SUCCESS
# by.globalinternational.vin ...SUCCESS
# ms.amhsbc.com ...FAIL
# www.dobitrade.com ...SUCCESS
# ww25.h2.da896.com ...SUCCESS
# ww5.richnessep.com ...SUCCESS
# testflight.apple.com ...SUCCESS
# testflight.apple.com ...SUCCESS
# testflight.apple.com ...SUCCESS
# www.tl6183.com ...SUCCESS
# www.shop168.fun ...SUCCESS
# www.guangfa226.com ...SUCCESS
# skdcoin.com ...SUCCESS
# fxauu.com ...SUCCESS
# m.cjgroup666.com ...SUCCESS
# h5.cmcpro.me ...FAIL
# bibox.shop ...FAIL
# bibox.vip ...SUCCESS
# ubtokens.com ...SUCCESS
# www.inst-global.com ...SUCCESS
# www.brilliancefx.com ...SUCCESS
# www.richeforex.com ...FAIL
# www.ruilonginvest.com ...SUCCESS
# www.tomahawkfx.com ...SUCCESS
# ng.cococo168.cn ...SUCCESS
# coinbene.coinbene.space ...SUCCESS
# coinbene.coinbene99.space ...SUCCESS
# lbank-exchanges.com ...SUCCESS
# lv.tocom.com.tw ...SUCCESS
# cabo.com.tw ...SUCCESS
# wa1.icoinitial.com ...SUCCESS
# taiwan.icoinitial.com ...SUCCESS
# h5.maxbe.cc ...SUCCESS
# goldcion2.net ...SUCCESS
# goldcion3.net ...SUCCESS
# download.dm9588.com ...SUCCESS
# newbitx.com ...SUCCESS
# warlockmarket.com ...SUCCESS
# wap.lyakrl.com ...SUCCESS
# lyakrl.com ...SUCCESS
# m.coindater.com ...SUCCESS
# www.decisionglobal.com ...SUCCESS
# btcturobox.com ...SUCCESS
# atlanticgaming99.com ...SUCCESS
# futurewallet.me ...SUCCESS
# bb.win16888.net ...SUCCESS
# download.fortuneranches.com ...SUCCESS
# optomal-coin.com ...FAIL
# noahcoinapp.com ...SUCCESS
# www.minersolar.net ...SUCCESS
# asdfzxcv.3azdh.com ...SUCCESS
# asdfzxcv.52yangmaozhuan.com ...SUCCESS
# bibox.ltd ...SUCCESS
# worldjuhe.com ...SUCCESS
# aetos-business.com ...SUCCESS
# diexchange.net ...FAIL
# jsjs2763jsjs8282as7app.com ...SUCCESS
# m.51aihuo.com ...SUCCESS
# www.fored.net ...SUCCESS
# bb.bbggttq.com ...SUCCESS
# www.weneco.io ...SUCCESS
# hunter.farm ...SUCCESS
# foxsolutionsgroup.com ...SUCCESS
# mkjmarkets.com ...FAIL
# www.sgdcep.com ...SUCCESS
# www.bitfly.site ...FAIL
# www.saxoint.com ...SUCCESS
# www.rockfortcrypto.com ...FAIL
# www.semua.in ...FAIL
# www.risheng58.com ...SUCCESS
# exbitoctopus.com ...FAIL
# hostglobals.com ...SUCCESS
# www.esgexsdh.site ...SUCCESS
# apollosw.com ...SUCCESS
# medusaexvip.site ...SUCCESS
# www.74cec.com ...SUCCESS
# h5.tokenplace.vip ...SUCCESS
# fortupath.com ...SUCCESS
# www.rockfortmarket.org ...FAIL
# www.nasapp1.com ...FAIL
# www.blockinpro.co ...SUCCESS
# jingsheng88.net ...SUCCESS
# making-m.net ...SUCCESS
# binanlink.buzz ...SUCCESS
# www.signgold.online ...SUCCESS
# m.goldplus.plus ...SUCCESS
# realbtcex.site ...SUCCESS
# www.pxj6666.com ...SUCCESS
# fcsl.newex.top ...SUCCESS
# futureassets.online ...SUCCESS
# www.orson66.com ...FAIL
# www.gileads.net ...FAIL
# www.zsdusd.com ...SUCCESS
# beta.acmetoy.com ...SUCCESS
# traden.xyz ...SUCCESS
# m.tmgn-fx.com ...FAIL
# mysignup.online ...SUCCESS
# sptbrokeruk.com ...SUCCESS
# funds-recovery.com ...SUCCESS
# www.tdku8.com ...SUCCESS
# m.xmzfxs.com ...SUCCESS
# theglobalpayback.com ...SUCCESS
# www.praiser.me ...SUCCESS
# www.tdrk1.com ...SUCCESS
# www.coinx.live ...FAIL
# www.prohopex.com ...FAIL
# bitkub.top ...SUCCESS
# wuan.bitvovo.asia ...SUCCESS
# www.idspro.xyz ...SUCCESS
# speedqueeninvestment.com ...FAIL
# crypto.miesiers.com ...SUCCESS
# www.qbctex.com ...FAIL
# www.amgofx.com ...SUCCESS
# www.zebpayex.vip ...FAIL
# member.lvpro.io ...SUCCESS
# www.newexglobal.com ...SUCCESS
# dot-ex.vip ...SUCCESS
# www.medusaex.net ...SUCCESS
# barex.site ...SUCCESS
# corexswap.com ...SUCCESS
# nas-financial.vip ...FAIL
# www.winwithmdc.com ...SUCCESS
# 24coinbitex.com ...SUCCESS
# blockexcom.pro ...SUCCESS
# www.tickexpro.vip ...FAIL
# www.goldcopytrade.com ...SUCCESS
# wap.bqbwap.xyz ...FAIL
# www.iqcinfor.com ...SUCCESS
# m.omgfinex.com ...FAIL
# www.spur51.com ...SUCCESS
# www.tmxex.net ...SUCCESS
# bocrypto.net ...SUCCESS
# www.romanticdatin.com ...SUCCESS
# client.hyfortune21.com ...SUCCESS
# p88.phatlife8.com ...SUCCESS
# www.okeexxc.com ...FAIL
# www.deshvip.net ...SUCCESS
# www.companyghj.com ...SUCCESS
# www.tmxex.site ...SUCCESS
# www.bestmine.cc ...SUCCESS
# vtmarkets.tw ...SUCCESS
# h5.uxmexglobal.com ...FAIL
# www.ishares.top ...SUCCESS
# www.starryluck.online ...SUCCESS
# beta.ikwb.com ...SUCCESS
# jointpro.global ...SUCCESS
# www.btchin.site ...FAIL
# www.impvcu.com ...SUCCESS
# sm444.tmgm9.net ...SUCCESS
# cbimful.com ...SUCCESS
# fttrading.net ...SUCCESS
# ifsmarkets.com ...SUCCESS
# www.impvcu.tw ...SUCCESS
# kisemeet.com ...SUCCESS
# inceptial.biz ...FAIL
# a003.baiy.world ...SUCCESS
# www.bit360che.me ...SUCCESS
# difc.pro ...FAIL
# www.nftbion.com ...SUCCESS
# aplexva.com ...SUCCESS
# protopone.com ...FAIL
# hirosetws.wiki ...FAIL
# www.hyfortune.live ...FAIL
# dfmt5.net ...SUCCESS
# h5.coinx.ai ...FAIL
# www.uniswapx3.com ...FAIL
# zygj.nxk86z0.cn ...SUCCESS
# scamrecoveryservices.com ...SUCCESS
# www.coincomex.com ...SUCCESS
# www.ramines.biz ...FAIL
# www.safir.com ...SUCCESS
# www.uniswapx3.vip ...FAIL
# www.blkexpro.com ...FAIL
# anderfx.com ...FAIL
# m.hotgolbal.com ...SUCCESS
# www.realbtcex.com ...SUCCESS
# goldcarrytrade.com ...SUCCESS
# www.hashexs.com ...FAIL
# www.od-688.com ...SUCCESS
# ifmbitex.com ...FAIL
# planetex.global ...FAIL
# www.btaxiesg.com ...FAIL
# www.ebcbitex.com ...FAIL
# www.dbontrade.com ...SUCCESS
# www.difxotc.com ...SUCCESS
# wap.cainvestw.vip ...FAIL
# www.adqc43qcffdd5255.xyz ...SUCCESS
# bigkane.com ...FAIL
# www.omhyusq.site ...SUCCESS
# cpgroupfinancial.com ...FAIL
# www.rgztop.com ...FAIL
# www.gsextrade.com ...FAIL
# dynamicmedia.club ...FAIL
# www.gomarketstw.store ...SUCCESS
# royalqs.com ...SUCCESS
# www.hyfortune.top ...FAIL
# kerrysexchange.com ...SUCCESS
# www.kerrysexchange.com ...SUCCESS
# dbestrad.com ...SUCCESS
# ac88.bitomax.net ...SUCCESS
# wap.bitcoinexap.vip ...FAIL
# pennsylvania912.supergiaying.com ...SUCCESS
# bceoin.club ...SUCCESS
# naxia2019.com ...SUCCESS
# www.sodglobal.cc ...SUCCESS
# client.hnd-global.com ...SUCCESS
# www.btcs.love ...SUCCESS
# www.binaricx.com ...SUCCESS
# nvpro.club ...FAIL
# www.star-clicks.com ...SUCCESS
# www.ltddir.com ...SUCCESS
# www.scythm.com ...SUCCESS
# i11l.top ...SUCCESS
# v.tb5lp8om.com ...FAIL
# vip.zynxm.com ...SUCCESS
# wlp.758563.top ...SUCCESS
# www.etranstws.com ...SUCCESS
# bba.frameb998.com ...SUCCESS
# ax8.frame882.com ...SUCCESS
# www.bibtc.net ...SUCCESS
# sp6.spurs588.com ...SUCCESS
# cfxintuo.xyz ...SUCCESS
# futurext.xyz ...SUCCESS
# gemina.gemini688.com ...SUCCESS
# gemins.geminitai.com ...SUCCESS
# euyns.jfbbi.com ...SUCCESS
# sdc.fizoption.com ...SUCCESS
# gl1688.91k.club ...FAIL
# gentercasino.com ...SUCCESS
# cash002.se888.net ...SUCCESS
# binary.xts.group ...SUCCESS
# www.yeekex.com ...FAIL
# www.coinskyex.com ...FAIL
# www.youtuex.com ...FAIL
# www.uniswap.care ...FAIL
# www.potatoex.io ...FAIL
# www.coinseaex.com ...FAIL
# www.maxptx.com ...SUCCESS
# www.letanx.vip ...FAIL
# www.polkaswaps.me ...FAIL
# www.bitmaster.cc ...FAIL
# m.coindeskex.com ...FAIL
# appdownload.io ...FAIL
# www.polkaswaps.vip ...FAIL
# wap.bitcoinex.vip ...SUCCESS
# wap.chiglodigits.com ...SUCCESS
# www.binancezh.co ...FAIL
# www.sdiedge.site ...SUCCESS
# www.minecoin.ai ...SUCCESS
# sejv888.com ...SUCCESS
# dianpushen.com ...SUCCESS
# dianpushen.com ...FAIL
# dianpushen.com ...FAIL
# dianpushen.com ...FAIL
# www.funds-back.com ...SUCCESS
# 26273.adqc43qcffdd5255.xyz ...SUCCESS
# caifuxt.xyz ...SUCCESS
# hkglobalwealth.com ...SUCCESS
# www.hkfttrade.com ...SUCCESS
# cmeclubs.com ...FAIL
# m.rifagala.com ...SUCCESS
# user.gotraysfx.com ...FAIL
# user.smartcontractslimited.com ...SUCCESS
# pccbase.com ...FAIL
# www.char10.com ...FAIL
# h5.char1well.xyz ...SUCCESS
# m.proex.io ...SUCCESS
# procoin888.com ...SUCCESS
# cityglobalfund.com ...SUCCESS
# turkiyfains.com ...SUCCESS
# www.globextradingltd.com ...SUCCESS
# ronexcoin.com ...SUCCESS
# krokcoin.com ...FAIL
# alliancefundbank.com ...SUCCESS
# swanfinanceltd.com ...SUCCESS
# capital-gain.ltd ...FAIL
# cryptoxender.com ...FAIL
# coinpryme.com ...SUCCESS
# fxcointrade.uk ...SUCCESS
# pfs-investment.com ...FAIL
# orangeglobalinvestment.com ...SUCCESS
# cncintel.com ...SUCCESS
# inergie.io ...SUCCESS
# www.fffipo.com ...SUCCESS
# www.fffipo.com ...SUCCESS
# t32tz.wtlongjiang.com ...SUCCESS
# easycoinbank.club ...SUCCESS
# suntoncapital.com ...SUCCESS
# wl28.cn ...SUCCESS
# bt088.cn ...SUCCESS
# m.worldcoin3.com ...SUCCESS
# digcoinseth.com ...SUCCESS
# cn.sungerfx.com ...SUCCESS
# web.centerter.net ...SUCCESS
# web.instaforex24.com ...SUCCESS
# uscg.vip ...SUCCESS
# gto01.wotrad.com ...FAIL
# fortune.excch.com ...SUCCESS
# sfoa.boayy.com ...SUCCESS
# bsb.kent6.com ...FAIL
# rs18.wingfr.com ...SUCCESS
# h2.kds55.com ...FAIL
# f9.maiaxx.com ...FAIL
# wwv.agilentt.com ...FAIL
# std.amtrei.com ...SUCCESS
# wa.fide7.com ...FAIL
# lb97.sarxd.com ...FAIL
# lb97.capitaori.com ...FAIL
# ss8888.gamccu.com ...FAIL
# dinghui.me ...SUCCESS
# hapfover.com ...FAIL
# hapfover.com ...FAIL
# ytqmtfx.com ...FAIL
# www.bit-deercoin.com ...FAIL
# lcryptos.com ...SUCCESS
# www.ytqmt-fx.com ...FAIL
# www.ytqmtfx.com ...FAIL
# www.bit-deercoirfx.com ...SUCCESS
# associate-fx.net ...SUCCESS
# www.dxycf.com ...FAIL
# www.dxycf.com ...FAIL
# jr.sukashare.net ...SUCCESS
# v6282.com ...SUCCESS
# android.mhefdz.com ...SUCCESS
# lcgmarketw.com ...SUCCESS
# ybgj8866.com ...SUCCESS
# sj.miss1you.com ...SUCCESS
# china.yazhougs.com ...SUCCESS
# ft1.wftuo.com ...SUCCESS
# biznesklass.com ...FAIL
# seethemonkey.com ...SUCCESS
# juassdhyhfs.com ...SUCCESS
# huyweidsyckdel.com ...SUCCESS
# huxikuanefslaegsj.com ...SUCCESS
# forex.forex-168.com ...SUCCESS
# 25fr.com ...SUCCESS
# financialcurrencyc.com ...FAIL
# bb.tianyue1122.com ...SUCCESS
# www.baocheng.live ...SUCCESS
# coin-isp.com ...SUCCESS
# www.jpccar380.com ...FAIL
# jpccar380.com ...FAIL
# download.howwpc.com ...SUCCESS
# imtoken-xx.com ...SUCCESS
# fc0628.com ...FAIL
# jj.ndskgenkgndgb.com ...SUCCESS
# glengoo.com ...FAIL
# www.byjrhk.com ...SUCCESS
# h5.meetlove66.com ...SUCCESS
# zxjt.af06.cn ...SUCCESS
# etf68.bxanys.com ...SUCCESS
# amber.bxanys.com ...SUCCESS
# aomge.com ...SUCCESS
# hkex.bxanys.com ...SUCCESS
# aomge.com ...SUCCESS
# xz.twbpxkai.com ...SUCCESS
# go.forexpro.shop ...SUCCESS
# yw.rlnsbfl.cn ...SUCCESS
# yw.wyhdkb.cn ...SUCCESS
# lineone.test.djkjapp.com ...SUCCESS
# lineone.test.djkjapp.com ...FAIL
# lineone.test.djkjapp.com ...FAIL
# lineone.test.djkjapp.com ...FAIL
# line4.test.djkjapp.com ...FAIL
# m.rongxin888.cc ...SUCCESS
# kucoin666.xyz ...SUCCESS
# www.dd2798.top ...FAIL
# hapfoverfx.com ...FAIL
# goldlionhk.com ...SUCCESS
# bl138.cc ...FAIL
# appvip.7ebit.vip ...SUCCESS
# www.btcbitex.net ...SUCCESS
# mgm.ycmdktsh.cn ...SUCCESS
# coincasso-13.cn ...SUCCESS
# tap.dierna.com ...SUCCESS
# tap.dfabu.com ...SUCCESS
# 6638we.com ...SUCCESS
# 62968756.com ...SUCCESS
# 85shouyou.com ...SUCCESS
# www.lnfexoption.com ...SUCCESS
# reforex1800.com ...SUCCESS
# www.omg-fin.me ...SUCCESS
# cgpaypro.vip ...SUCCESS
# cumberland.monster ...SUCCESS
# fd2291.com ...SUCCESS
# www.pkex6.com ...SUCCESS
# www.jinletiyu.com ...SUCCESS
# uncleblockings.com ...SUCCESS
# www.gileads.info ...FAIL
# linktr.ee ...SUCCESS
# midoin.link ...SUCCESS
# atlanticgamingshare.com ...SUCCESS
# www.northernrich.com ...SUCCESS
# h5.tpgwell.xyz ...SUCCESS
# www.tpg6.com ...FAIL
# h5.trade73383.xyz ...SUCCESS
# aaexchain.com ...SUCCESS
# tik668.com ...FAIL
# www.chainlity.com ...SUCCESS
# hangtaiwealth.com ...SUCCESS
# mtradeplus.com ...SUCCESS
# www.gdr66688.com ...SUCCESS
# sfh5.shanxuhui.top ...SUCCESS
# www.bisholding.asia ...SUCCESS
# suntonfx.com ...SUCCESS
# netinvestment.ltd ...SUCCESS
# h5.capgoin.com ...FAIL
# h5.cap1688.com ...FAIL
# www.myrshop.com ...SUCCESS
# dolo.bitmex66.com ...SUCCESS
# h5.trade97998.xyz ...SUCCESS
# rsjrjys.com ...SUCCESS
# wap.bitexsap.vip ...SUCCESS
# bcatw.cc ...FAIL
# www.mbo68.com ...FAIL
# bfose.dfcinto.com ...FAIL
# gar.iqcoption.com ...SUCCESS
# idc.rgztw.com ...FAIL
# bodhisattva.kodakby.com ...SUCCESS
# global-exptrade.com ...SUCCESS
# payback-ltd.com ...SUCCESS
# hs998.hsbjingding.net ...SUCCESS
# investors.effectivein.com ...SUCCESS
# ydfxm.com ...SUCCESS
# uoetsys.com ...SUCCESS
# liyeplimal.net ...SUCCESS
# monetory.io ...SUCCESS
# ifs.ifsmorgan.com ...SUCCESS
# www.jiashk.com ...SUCCESS
# 1999v21.com ...SUCCESS
# www.k58586.com ...SUCCESS
# weixin.shicaiweihuo.com ...SUCCESS
# weixin.shicaiweihuo.com ...SUCCESS
# weixin.shicaiweihuo.com ...SUCCESS
# h5.orientalwe.com ...SUCCESS
# h5.huilitrad.com ...FAIL
# h5.fxcmlay.com ...FAIL
# h5.bcointd.com ...FAIL
# www.tii3tnw.life ...FAIL
# adzxz.fafubu.mobi ...SUCCESS
# amber.anygaladay.com ...FAIL
# etf68.anygaladay.com ...FAIL
# aax.anygaladay.com ...FAIL
# hkex.anygaladay.com ...FAIL
# gb.anygaladay.com ...FAIL
# coinmagic.vip ...FAIL
# www.coinbuck.vip ...FAIL
# www.magiccoin.vip ...FAIL
# h5.cc.lerjin.com ...SUCCESS
# newbitba.xyz ...FAIL
# wap.yomaniap.vip ...SUCCESS
# wap.nexap.vip ...SUCCESS
# wap.ucoinn.xyz ...FAIL
# crypto-mining.farm ...SUCCESS
# www.analyticssteps.com ...SUCCESS
# trade.lem-tw.com ...SUCCESS
# wap.eminimp.top ...SUCCESS
# wap.eminim.vip ...SUCCESS
# wap.ba2308.com ...SUCCESS
# gray.asia ...FAIL
# m.jindaguoji.net ...SUCCESS
# www.cointsla.com ...SUCCESS
# dfjk.xyz ...FAIL
# dcss.xyz ...FAIL
# tfee.xyz ...SUCCESS
# grfw.xyz ...SUCCESS
# blgc.xyz ...SUCCESS
# www.kabitw.com ...SUCCESS
# kabitw.com ...SUCCESS
# uniswapex.vip ...FAIL
# mm.mgm2058.com.cn ...SUCCESS
# earning-club.com ...SUCCESS
# m.wenlvnews.com ...SUCCESS
# www.sport656.com ...SUCCESS
# ristversos.com ...SUCCESS
# wnc.lijun88.live ...SUCCESS
# mgm.gzsybj.cn ...FAIL
# tmgmpro.xyz ...SUCCESS
# www.yptd-music.cn ...SUCCESS
# 728fb59042cd6093.007r.cn ...SUCCESS
# www.ikjzd.com ...SUCCESS
# atranding.club ...FAIL
# www.yypengyou.com ...SUCCESS
# www.lovemeet1.com ...SUCCESS
# web.ng117.com ...SUCCESS
# tg.cmeusa.pw ...SUCCESS
# www.ob011.com ...SUCCESS
# ttcd.xyz ...SUCCESS
# www.myjt6.com ...SUCCESS
# zygj.lkwnmt.work ...SUCCESS
# only.qnhzrq.work ...SUCCESS
# 1.jihg2u1.xyz ...SUCCESS
# wcointraing.com ...SUCCESS
# www.lpbyduq.cn ...FAIL
# gl.m9a03gm.cn ...SUCCESS
# www.zfxs.site ...SUCCESS
# only.wyxwegn.cn ...FAIL
# chosenone.io ...SUCCESS
# bscoinvip.com ...FAIL
# costcovips.com ...FAIL
# brtopapp.com ...SUCCESS
# bstopapp.com ...FAIL
# sstopapp.com ...SUCCESS
# bs2021.com ...FAIL
# absvip3366.com ...SUCCESS
# supr5525.com ...SUCCESS
# bh90909.com ...SUCCESS
# www.seventrad.com ...SUCCESS
# binarywealthtradefx.com ...SUCCESS
# excoin55.com ...SUCCESS
# cryptodigitaloptions.com ...SUCCESS
# trader.egmforex.vip ...FAIL
# www.spe29.com ...FAIL
# www.lazada80.com ...FAIL
# www.bsn56.com ...FAIL
# www.trw60.com ...SUCCESS
# www.joom61.com ...SUCCESS
# www.mymicedb.com ...FAIL
# www.oub89.com ...SUCCESS
# www.usgfx.asia ...FAIL
# alanfx.cn ...SUCCESS
# jiaxinguk.com ...SUCCESS
# fubxinnet.com ...FAIL
# taijinxitou.com ...SUCCESS
# www.yidejia.com ...SUCCESS
# zoro-forex.com ...SUCCESS
# kriptofuture.com ...SUCCESS
# www.alphafxgroup.io ...SUCCESS
# cryptocars.me ...SUCCESS
# user.jslink.vip ...FAIL
# dinos.veryrich168.online ...SUCCESS
# www.samtradefx.com ...SUCCESS
# www.kayli.cc ...SUCCESS
# www.bitebcex.com ...FAIL
# acceptrade.com ...SUCCESS
# financialmanagement.nsxaq.com ...FAIL
# h51.kanx9.com ...SUCCESS
# taiwan.smpstrades.com ...SUCCESS
# www.650025.com ...SUCCESS
# www.broann.net ...SUCCESS
# hgou1.com ...FAIL
# ez178.net ...SUCCESS
# swaggame.online ...SUCCESS
# www.drcfx.com ...SUCCESS
# mkj.cc ...FAIL
# etherscan.io ...SUCCESS
# hitechempire.com ...SUCCESS
# alca-central.com ...FAIL
# www.rockfortmarket.net ...FAIL
# www.bcioms.com ...SUCCESS
# www.zh-holding.com ...FAIL
# darv.moma.website ...SUCCESS
# orangeglobalinvest.com ...SUCCESS
# nflix.media ...FAIL
# www.prizmbit.vip ...FAIL
# www.kutoken.io ...SUCCESS
# www.bbkx.com ...SUCCESS
# binance2vip.com ...SUCCESS
# tgqa1.com ...SUCCESS
# 15dy.me ...SUCCESS
# coinx.ai ...FAIL
# zygj.p3j0684.cn ...SUCCESS
# www.tdku1.com ...SUCCESS
# www.cow4stock.com ...FAIL
# www.nas-vip.com ...FAIL
# appdown.acexusdt.com ...SUCCESS
# mbo-888.com ...SUCCESS
# thcjx.pro ...SUCCESS
# www.ghuard.com ...SUCCESS
# www.zhinter.com ...FAIL
# bnbdt.pro ...FAIL
# bnbdt.pro ...FAIL
# m.lamxpros.com ...FAIL
# sunvest.app ...SUCCESS
# solwallet.cc ...SUCCESS
# www.impvcu.net ...SUCCESS
# officialsignups.com ...SUCCESS
# laoluofenfa.com ...SUCCESS
# download.liqtrad.com ...FAIL
# www.bitmarket.ai ...SUCCESS
# coinsbase.world ...SUCCESS
# www.asiapac.online ...SUCCESS
# m.fntm.app ...SUCCESS
# www.ciglobal.me ...FAIL
# down.xckej.org ...SUCCESS
# www.syuanltd.com ...SUCCESS
# mcdex.app ...SUCCESS
# www.richtech.live ...FAIL
# tb1.ecdhbcc.com ...SUCCESS
# tobgogobk.com ...SUCCESS
# 988cp.net ...SUCCESS
# coin-pro.global ...SUCCESS
# www.ciizurnfx.com ...SUCCESS
# www.bnb-dt.pro ...FAIL
# www.fxcii.com ...SUCCESS
# bitcomexvip.com ...FAIL
# vip9453.com ...SUCCESS
# www.imteif.com ...SUCCESS
# us.marketsfortw.top ...FAIL
# bitcomex.site ...FAIL
# www.ebcxex.com ...SUCCESS
# inceptial.com ...SUCCESS
# mhdgold.com ...SUCCESS
# cuw-invest.com ...SUCCESS
# m.cxmglobe.com ...FAIL
# nisajp.nisajp.com ...SUCCESS
# www.ucak6.com ...SUCCESS
# wuan.bitvovo.website ...SUCCESS
# ios886.com ...SUCCESS
# hao.aifund.world ...SUCCESS
# a005.8legend.net ...SUCCESS
# ehvx.pro ...SUCCESS
# www.fxd20pro.com ...FAIL
# www.hbtlite.vip ...FAIL
# www.lipuex.com ...SUCCESS
# www.downloadcg.com ...SUCCESS
# www.downloadcg.com ...SUCCESS
# www.downloadcg.com ...SUCCESS
# www.downloadcg.com ...SUCCESS
# titecoin.pro ...FAIL
# titecoin.pro ...FAIL
# m.wwg-fx.com ...SUCCESS
# caasiainvest.com ...FAIL
# www.eocfx.com ...FAIL
# www.pxj333.com ...SUCCESS
# www.medusaex.site ...SUCCESS
# neptuneblock.com ...SUCCESS
# relforex3650.com ...FAIL
# ifadfortw.com ...SUCCESS
# www.bontopex.com ...SUCCESS
# www.liqucoins.com ...FAIL
# axiexchange.net ...FAIL
# m.nf35.com ...SUCCESS
# vtmarkets.xyz ...SUCCESS
# www.odi68.com ...SUCCESS
# adxnbit.com ...SUCCESS
# www.cow4stock.tw ...FAIL
# www.fxtcointa.com ...FAIL
# www.bitcoinmine.vip ...SUCCESS
# www.potex.com ...SUCCESS
# www.idexsvip.com ...FAIL
# pis10.difxotc.com ...SUCCESS
# huobi.snapgoo.com ...SUCCESS
# ff.tyangcheng668.com ...SUCCESS
# jyjtrade.com ...FAIL
# anderfix.com ...FAIL
# www.medusaex.com ...SUCCESS
# finvestings.com ...SUCCESS
# goldensolarpower.com ...SUCCESS
# st88168.tobtobgo.com ...SUCCESS
# ptex.pro ...FAIL
# www.nas-app.com ...FAIL
# account.forex40.com ...FAIL
# blueshield-ex.com ...FAIL
# www.iexspartner.com ...SUCCESS
# www.qfii68.com ...SUCCESS
# www.bitfx-traders.com ...SUCCESS
# merrillfortw.com ...FAIL
# www.tickmillex.com ...FAIL
# upbit.wang ...SUCCESS
# mt4-group.com ...SUCCESS
# www.promkfx.com ...SUCCESS
# www.cyprotw.tw ...FAIL
# pamm.forexhub.world ...SUCCESS
# bitcomexvip.site ...FAIL
# www.forex43.com ...FAIL
# download.lqudcoin.com ...FAIL
# hqwhz.tms2830.cn ...SUCCESS
# gaeex.com ...FAIL
# hkexpro.xyz ...SUCCESS
# m.ncmalluk.com ...FAIL
# bitazza.com ...SUCCESS
# www.tfxi2.com ...SUCCESS
# iju888.net ...SUCCESS
# hb78.bet ...SUCCESS
# www.sbbet80.com ...FAIL
# www.im.academy ...SUCCESS
# maimaishouyou.com ...FAIL
# d5857m.win666.us ...FAIL
# unlisted.io ...SUCCESS
# show-chain.net ...FAIL
# my.xm-intl.com ...SUCCESS
# www.hjqwer.com ...SUCCESS
# www.exnesstw.com ...SUCCESS
# www.supaytw.com ...FAIL
# tw.kpcbtws.com ...SUCCESS
# agyayu.com ...SUCCESS
# www.jpmorgantw.com ...FAIL
# m.365s666.com ...SUCCESS
# crm.zoro-forex.com ...SUCCESS
# m.bit-herald.com ...SUCCESS
# nycex.org ...FAIL
# 89c49a559.com ...SUCCESS
# nivzmyk.cn ...SUCCESS
# qqkkd.com ...SUCCESS
# dpp.wwjkkq.com ...SUCCESS
# down.oookapp.com ...SUCCESS
# kkggr.com ...SUCCESS
# zaxhiyw.cn ...SUCCESS
# downloadappios.com ...SUCCESS
# ashanimultimedia.com ...SUCCESS
# h5.m87aybsadweb.xyz ...FAIL
# www.bknsxx.com ...SUCCESS
# century.tss28.vip ...SUCCESS
# gogames.cc ...SUCCESS
# 96517.cc ...SUCCESS
# 67183.cc ...SUCCESS
# fkforextw.com ...SUCCESS
# www.ghjr-tw.com ...SUCCESS
# www.xinghaijys.com ...SUCCESS
# www.owllex.com ...SUCCESS
# oheho.com ...SUCCESS
# www.gic.club ...SUCCESS
# nonfungiblecoin.net ...SUCCESS
# www.avatradetw.cn.com ...SUCCESS
# aeyujmhx.gjtyzs.cn ...SUCCESS
# wardirectory.com ...SUCCESS
# royalq-bot.com ...SUCCESS
# www.gardala.com ...SUCCESS
# www.wshops8848.com ...SUCCESS
# www.gangstacum.com ...FAIL
# www.infocoinnetwork.com ...SUCCESS
# www.alichainex.com ...SUCCESS
# tjcp6666.com ...SUCCESS
# www.futuojituan-global.com ...SUCCESS
# 17381738.com ...SUCCESS
# www.yuhengfx.com ...FAIL
# dd.zaoboshi.vip ...SUCCESS
# fd.iconpro.vip ...FAIL
# h5.jpmwell.xyz ...SUCCESS
# oua.snxbvvq.xyz ...SUCCESS
# jhq.s8h3bs.xyz ...FAIL
# dfa.sbv4gjaa.xyz ...FAIL
# mko.sbxzvvh124.xyz ...SUCCESS
# nas.sbzvh41sr.xyz ...SUCCESS
# www.huanqiushangcheng.com.tw ...SUCCESS
# aa.9876544.com ...SUCCESS
# fxview-tw.com ...SUCCESS
# m.tyc2345.cc ...FAIL
# www.haoqinlv.cn ...FAIL
# dg.diguoapp.com ...SUCCESS
# dg.longdivip.com ...SUCCESS
# huobi-support.co ...FAIL
# paybis.thegoodd.com ...SUCCESS
# downloadomg.wheppc.com ...SUCCESS
# www.lmaxfortw.com ...FAIL
# www.yulonfortw.com ...SUCCESS
# www.marketsfortw.cc ...SUCCESS
# www-ysb.com ...SUCCESS
# www.208btc.com ...SUCCESS
# www.mark6666.com ...FAIL
# gaosheng186.com ...SUCCESS
# download.mcpcu.com ...SUCCESS
# h5.cap2one.com ...FAIL
# h5.capsmart.top ...SUCCESS
# h5.capital8888.com ...FAIL
# www.capital119.com ...FAIL
# h5.cap880.com ...FAIL
# h5.capital110.com ...FAIL
# h5.capital199.com ...FAIL
# goldmansachs1995.com ...SUCCESS
# www.bitterwalk.com ...SUCCESS
# yuntonghbgyvf.top ...FAIL
# huobi-ok.com ...SUCCESS
# www.78520.com ...SUCCESS
# www.regain-capital.com ...SUCCESS
# www.xinhex.net ...FAIL
# portalrealm.co ...FAIL
# lunartigers.com ...SUCCESS
# down.tbkf29817.com ...SUCCESS
# cpiait.com ...SUCCESS
# www.ecgvlog.com ...SUCCESS
# sb.gene07.com ...FAIL
# tw2.poi72.com ...FAIL
# berks.ikamiia.com ...FAIL
# gwwwe.ttcorsd.com ...FAIL
# xgame.vvt1.ff88.online ...SUCCESS
# xgame.gd4.sunbur77.club ...FAIL
# bdiexchange.hyauu.com ...SUCCESS
# www.sdy88861.com ...SUCCESS
# www.sdy9994.com ...SUCCESS
# h5.trade15318.xyz ...FAIL
# h5.trade22213.xyz ...FAIL
# h5.trade05035.xyz ...FAIL
# h5.trade99372.xyz ...FAIL
# h5.trade82555.xyz ...FAIL
# h5.hifly86933.xyz ...SUCCESS
# h5.hifly18277.xyz ...FAIL
# hyhy.pj2nnas.xyz ...FAIL
# tmys.pasd1231.xyz ...SUCCESS
# hqq.uyban.club ...SUCCESS
# hqq.uyban.club ...SUCCESS
# suy.jusvvxa.xyz ...FAIL
# eew.jasbb1231.xyz ...SUCCESS
# suy.jusvvxa.xyz ...FAIL
# eew.jasbb1231.xyz ...SUCCESS
# c67.kjxyabdcva.xyz ...SUCCESS
# eew.jasbb1231.xyz ...SUCCESS
# bvc.vghsddhcs.online ...SUCCESS
# bvc.vghsddhcs.online ...SUCCESS
# bvc.vghsddhcs.online ...SUCCESS
# fdw.jas6aga2.xyz ...SUCCESS
# suy.jusvvxa.xyz ...FAIL
# bvc.vghsddhcs.online ...SUCCESS
# ttr.jasnvv167.xyz ...SUCCESS
# bvc.vghsddhcs.online ...SUCCESS
# fdw.jas6aga2.xyz ...SUCCESS
# xhf.hiudhfiu.store ...SUCCESS
# bvc.vghsddhcs.online ...SUCCESS
# asdhe.resuasf.vip ...FAIL
# rol.kcoin.zone ...SUCCESS
# www.antusdt.com ...FAIL
# jiunet.tech ...SUCCESS
# asdf.lxdfvon.cn ...SUCCESS
# ylvip3905.com ...SUCCESS
# www.82upgrade.xyz ...SUCCESS
# www.liberal211cu.xyz ...SUCCESS
# kcs941.com ...FAIL
# www.tien-iu.com ...SUCCESS
# likeeshare.com ...SUCCESS
# likeeshare.com ...SUCCESS
# bmex.vip ...SUCCESS
# www.pyq1270634.com ...SUCCESS
# acxcenter.com ...SUCCESS
# lbankmax.com ...SUCCESS
# bitchembroker.com ...SUCCESS
# symboldata.com ...SUCCESS
# bitchemtop.com ...SUCCESS
# zbgmax.com ...SUCCESS
# blockinand.com ...SUCCESS
# cmegroupand.com ...SUCCESS
# fxcmplu.com ...SUCCESS
# zbgsep.com ...SUCCESS
# fxccmax.com ...SUCCESS
# fxccbroker.com ...SUCCESS
# fxccb2c.com ...SUCCESS
# blockincenter.com ...SUCCESS
# utipmax.com ...SUCCESS
# fxcmmax.com ...SUCCESS
# fxcmand.com ...SUCCESS
# bitewangbox.com ...SUCCESS
# cmegroupmax.com ...SUCCESS
# etsuhdtb2c.com ...SUCCESS
# lbankcenter.com ...SUCCESS
# bitchemmax.com ...SUCCESS
# blockintop.com ...SUCCESS
# orangexmax.com ...SUCCESS
# blgajd.com ...SUCCESS
# fxcmsep.com ...SUCCESS
# etsuhdtmax.com ...SUCCESS
# etrademaxs.com ...FAIL
# orangexbox.com ...SUCCESS
# bitchemdtc.com ...SUCCESS
# lbanktop.com ...SUCCESS
# fxcmcenter.com ...SUCCESS
# acxmax.com ...SUCCESS
# arcoinadm.com ...SUCCESS
# meiwork.online ...SUCCESS
# txxd668.com ...SUCCESS
# www.icetrad.com ...FAIL
# www.coindeskweb68.com ...FAIL
# www.rjfinancialpro.vip ...FAIL
# www.84962t56s.com ...SUCCESS
# www.gats.work ...SUCCESS
# bingbontw.co ...FAIL
# www.coinmarkets123.com ...SUCCESS
# www.bitfinex963.com ...SUCCESS
# www.bmexglobal822.xyz ...SUCCESS
# www.bitbts.com ...FAIL
# www.sygnexc.com ...SUCCESS
# www.sygnexc.com ...SUCCESS
# www.futabas.app ...SUCCESS
# www.bceuae.com ...SUCCESS
# www.trade71461.xyz ...FAIL
# bitnewscoin.com ...FAIL
# www.zy2q.cn ...SUCCESS
# mobi.fullwin.org ...FAIL
# www.ubsjp.com ...SUCCESS
# www.lakewebes.com ...SUCCESS
# www.oamdi.xyz ...FAIL
# www.itk-ex.com ...SUCCESS
# smbcco.com ...FAIL
# js75051.com ...SUCCESS
# www.yhks.app ...SUCCESS
# www.biki111.com ...SUCCESS
# www.elparii.com ...SUCCESS
# www.xinlianca.xyz ...FAIL
# 103.193.243.93 ...FAIL
# www.bnexsusdt.com ...SUCCESS
# 150.107.2.59 ...FAIL
# www.oslint.com ...FAIL
# www.huibetd.com ...FAIL
# www.coinsboxweb68.com ...SUCCESS
# www.zy8618.com ...SUCCESS
# www.tencentwm.com ...SUCCESS
# www.blackrockweb68.com ...SUCCESS
# www.klinetrade.com ...SUCCESS
# www.gmb2tw.com ...SUCCESS
# www.binancevip.co ...FAIL
# www.letian1122.com ...FAIL
# www.letian1122.com ...FAIL
# www.bitzontd.com ...SUCCESS
# www.gpwtrad.com ...FAIL
# www.bnexusdts.com ...SUCCESS
# www.deribitgl.com ...FAIL
# www.bitmax.ink ...SUCCESS
# www.dootrade123.com ...FAIL
# www.2sehk.top ...SUCCESS
# www.bicointweb68.com ...FAIL
# www.koorbit.com ...FAIL
# www.ctreeint.com ...FAIL
# www.hbxhfh.com ...SUCCESS
# www.letian1122.com ...FAIL
# www.s656819a6.com ...SUCCESS
# www.ggbgg.xyz ...FAIL
# 103.193.243.92 ...FAIL
# www.letian1122.com ...FAIL
# www.btexw.xyz ...FAIL
# 103.193.243.93 ...FAIL
# www.cainvest.vip ...FAIL
# www.capitaloneu.vip ...SUCCESS
# www.letian1122.com ...FAIL
# hangme88.com ...SUCCESS
# www.auchelos.vip ...SUCCESS
# www.gonsin.vip ...SUCCESS
# www.coinhui.net ...SUCCESS
# www.forexdce.com ...FAIL
# www.jidan8888.com ...SUCCESS
# www.aexbitpro.vip ...FAIL
# hkfihg.newfund.xyz ...SUCCESS
# www.jidan8888.com ...FAIL
# www.bikan.net.cn ...FAIL
# www.fgweb68.com ...FAIL
# www.jidan8888.com ...FAIL
# atfxstafy.com ...FAIL
# www.dxdpro.com ...FAIL
# www.bvproglobal.com ...FAIL
# www.hongqi689.com ...FAIL
# www.fhbinvest.com ...SUCCESS
# www.onokafx.com ...SUCCESS
# www.sshenwan.com ...FAIL
# www.sixglba.com ...FAIL
# www.lctpglobal.com ...FAIL
# www.pecco123.com ...SUCCESS
# www.oslarl.com ...FAIL
# www.ahxex.com ...SUCCESS
# www.worldfistw.xyz ...FAIL
# www.voyagerfy.com ...FAIL
# www.nyseurone.com ...SUCCESS
# oslint.com ...FAIL
# www.cmeusa.club ...FAIL
# www.axagloballine.com ...FAIL
# www.kickexint.com ...FAIL
# www.jpmcos.vip ...FAIL
# www.11shop.vip ...SUCCESS
# www.bitcoinexos.vip ...FAIL
# www.mhn.app ...SUCCESS
# www.trade28398.xyz ...FAIL
# www.ceobi829.xyz ...SUCCESS
# www.ctoweb68.com ...SUCCESS
# www.fls77.xyz ...SUCCESS
# www.qtradeusa.com ...FAIL
# www.sushilimited.com ...SUCCESS
# www.kickint.com ...SUCCESS
# www.bqbbqb.vip ...FAIL
# www.cmeavip.com ...FAIL
# www.efurtrad.com ...SUCCESS
# capitaloneu.vip ...SUCCESS
# www.zbgst.com ...SUCCESS
# www.atfxstafy.com ...FAIL
# www.bblsint.com ...SUCCESS
# www.eurexbre.com ...SUCCESS
# www.binanctd.top ...FAIL
# www.bsxglb.com ...SUCCESS
# www.cmetrad.com ...FAIL
# www.cointreefx.com ...FAIL
# www.fxcmlay.com ...FAIL
# www.fxtmtd.com ...FAIL
# www.gicfuture.com ...FAIL
# www.hbtoponei.com ...FAIL
# www.hcextd.com ...FAIL
# www.hkextd.top ...FAIL
# www.krakeniec.com ...FAIL
# www.lctpinte.com ...FAIL
# www.mufgstal.com ...FAIL
# www.ndsuntrad.com ...SUCCESS
# www.aaxvipa.com ...FAIL
# www.becexgbl.com ...SUCCESS
# www.bitfinexr.com ...FAIL
# www.borsaint.com ...FAIL
# www.coinseaexfy.com ...SUCCESS
# www.cwgvip.com ...FAIL
# www.cxmtrad.com ...FAIL
# www.gdacvip.com ...FAIL
# www.gicvipa.com ...SUCCESS
# www.iggtrad.com ...SUCCESS
# www.krakenca.com ...SUCCESS
# www.lunotrade.buzz ...SUCCESS
# www.msjint.com ...SUCCESS
# www.nzxingbl.com ...FAIL
# www.saxoial.com ...SUCCESS
# www.uuexna.com ...SUCCESS
# www.wbgtd.com ...FAIL
# www.znncnb.com ...SUCCESS
# www.cibsiiepro.xyz ...SUCCESS
# www.blttrex.me ...SUCCESS
# www.trade75980.xyz ...FAIL
# www.ozzoco.xyz ...FAIL
# www.wwfos.vip ...SUCCESS
# www.lt563.com ...FAIL
# hrtrad.com ...FAIL
# bitzontd.com ...FAIL
# www.potatomedia.co ...FAIL
# www.yodacapital.net ...SUCCESS
# www.bitoceantrad.com ...FAIL
# futaba.bet ...SUCCESS
# www.tm-sxy.com ...SUCCESS
# www.tcexweb68.com ...FAIL
# www.ctowebes.com ...SUCCESS
# www.rfxau.com ...FAIL
# www.hotcpro.vip ...SUCCESS
# www.lsryoc.cn ...SUCCESS
# vouch.xyz.com ...SUCCESS
# www.gfeasg.com ...SUCCESS
# www.hioxex.com ...SUCCESS
# www.ahaqlc.com ...FAIL
# www.hqcjq123.com ...FAIL
# www.kkcoinsc.com ...SUCCESS
# www.tgmgex.com ...SUCCESS
# rdnysedc.com ...FAIL
# www.hotbitcoin.vip ...SUCCESS
# www.bitexos.vip ...SUCCESS
# 2021wbf.com ...FAIL
# www.fxddos.vip ...SUCCESS
# www.lakeweb68.com ...FAIL
# www.fxcmrsa.com ...FAIL
# www.ssjjf8.com ...SUCCESS
# www.problockfolio.xyz ...SUCCESS
# www.flash822.xyz ...SUCCESS
# www.bairradaforex.com ...SUCCESS
# www.eh2e5ra.com ...SUCCESS
# www.bqbss.vip ...SUCCESS
# coinexos.vip ...FAIL
# www.qicsex.com ...SUCCESS
# www.hsrhgs.com ...SUCCESS
# www.axaline01.com ...FAIL
# www.hrkj8.com ...SUCCESS
# www.cobos.vip ...FAIL
# www.aqdav.com ...SUCCESS
# www.cainvests.vip ...SUCCESS
# www.uexos.vip ...FAIL
# down.qianmingwww.com ...SUCCESS
# www.yhk.bet ...SUCCESS
# soprasteriadcweb.com ...SUCCESS
# www.simuliadcline.com ...SUCCESS
# www.simuliadcweb.com ...SUCCESS
# www.ff7tse0.cn ...SUCCESS
# www.hotcoinpro.vip ...SUCCESS
# www.ciextrade.com ...FAIL
# www.proexchangea.com ...SUCCESS
# www.cexuary.com ...SUCCESS
# www.eminiss.vip ...SUCCESS
# www.mhn.bet ...SUCCESS
# www.bhpt.io ...FAIL
# www.fxcmts.com ...SUCCESS
# www.agiobais.com ...FAIL
# www.bnexsusdts.com ...SUCCESS
# www.oslau.com ...SUCCESS
# www.ruilong-markets.com ...SUCCESS
# www.creatorexchange1.com ...FAIL
# www.simuliadc01.com ...SUCCESS
# www.eminss.top ...SUCCESS
# www.fglines.com ...SUCCESS
# www.zbweb01.com ...SUCCESS
# www.yomani.vip ...SUCCESS
# www.gebex.bet ...FAIL
# www.fglines.com ...SUCCESS
# www.fglines.com ...SUCCESS
# www.fglines.com ...SUCCESS
# www.fglines.com ...SUCCESS
# www.fglines.com ...SUCCESS
# www.fglines.com ...SUCCESS
# www.nyseuroneau.com ...SUCCESS
# www.problockfolio.xyz ...SUCCESS
# www.greenstans.com.tw ...SUCCESS
# www.cali8888.net ...SUCCESS
# pp05.twprc1688.com ...SUCCESS
# www.yhk88.app ...SUCCESS
# www.cmebil.com ...FAIL
# www.trade69878.xyz ...FAIL
# www.fglines.com ...SUCCESS
# www.fglines.com ...SUCCESS
# www.gebex.app ...FAIL
# www.koorbitau.com ...SUCCESS
# www.okexxq.com ...FAIL
# www.bikios.vip ...SUCCESS
# www.upedexchain.top ...SUCCESS
# ameritradetw.tdamr.com ...FAIL
# www.hmexs.com ...SUCCESS
# www.nasdaqwincoin.com ...SUCCESS
# www.hkbizzan.com ...SUCCESS
# www.ruxcoin.com ...SUCCESS
# www.aausforex.xyz ...SUCCESS
# www.blockpro.vip ...SUCCESS
# www.cechkk.com ...SUCCESS
# www.upedexchain.cc ...SUCCESS
# www.cainvest.space ...SUCCESS
# www.56rh9q.com ...SUCCESS
# www.arum.vip ...SUCCESS
# www.coinfoex.com ...FAIL
# www.firshop.com ...SUCCESS
# www.zy89999.com ...SUCCESS
# www.gicaue.com ...SUCCESS
# www.nexss.vip ...SUCCESS
# www.yhk888.io ...SUCCESS
# www.bmhex.com ...SUCCESS
# www.zaibuxingjiuchiji.com ...FAIL
# www.1818556601.com ...SUCCESS
# www.wiexex.com ...SUCCESS
# www.bione123.com ...SUCCESS
# www.zaibuxingjiuchiji.com ...FAIL
# www.hongqi689.com ...FAIL
# www.zmgty.top ...SUCCESS
# df.hljcpmn.cn ...SUCCESS
# www.lexincaifu.com ...SUCCESS
# www.gpvnznf.cn ...SUCCESS
# www.boniryweb.com ...SUCCESS
# www.fglines.com ...SUCCESS
# www.okexxe.com ...SUCCESS
# www.pkxepro.xyz ...FAIL
# www.yomanic2c.com ...SUCCESS
# www.catex01.xyz ...SUCCESS
# www.kucoinex.com ...SUCCESS
# www.oamdi.vip ...SUCCESS
# www.bitbankchain.com ...FAIL
# www.hifly89098.top ...SUCCESS
# www.bbxotc.co ...FAIL
# www.voyagerauq.com ...SUCCESS
# www.makersapp.top ...SUCCESS
# www.newbnexusdt.com ...SUCCESS
# www.chainalysisline.com ...SUCCESS
# www.chainalysisweb.com ...SUCCESS
# www.bitcpr.xyz ...FAIL
# www.becexau.com ...SUCCESS
# www.uinssde.com ...FAIL
# ag666.com ...FAIL
# www.bikuex.com ...SUCCESS
# www.hbet146.com ...SUCCESS
# www.shibo292.com ...SUCCESS
# www.coinbasesj.vip ...SUCCESS
# www.wnmex.com ...SUCCESS
# www.zbos.space ...SUCCESS
# www.360biki.com ...SUCCESS
# www.omgos.vip ...SUCCESS
# www.lctpue.com ...SUCCESS
# www.koinimtd.com ...FAIL
# www.nexos.vip ...FAIL
# www.coinprobin.cc ...SUCCESS
# www.asibawebs.com ...SUCCESS
# www.trade58579.xyz ...SUCCESS
# www.fglines.com ...SUCCESS
# www.ghkm.app ...SUCCESS
# www.solnanab.ltd ...SUCCESS
# www.kuswap.top ...SUCCESS
# www.prcbroker.vip ...SUCCESS
# www.cmegos.vip ...FAIL
# www.onetoken.io ...FAIL
# www.bitfinexs.top ...SUCCESS
# www.zblines.com ...SUCCESS
# www.eightd.xyz ...FAIL
# www.wwfss.top ...SUCCESS
# www.ruilongforex.com ...SUCCESS
# www.cmegroup.top ...SUCCESS
# www.bitf885.com ...SUCCESS
# www.biki365.com ...SUCCESS
# www.mtokenweb68.com ...SUCCESS
# www.fglines.com ...SUCCESS
# www.xm90.vip ...SUCCESS
# bitqq.vip ...SUCCESS
# www.bitglobal.pro ...SUCCESS
# down.ghjdfbe.com ...FAIL
# xcwxpx.cn ...SUCCESS
# m.tesdufh.cn ...FAIL
# h5.kpcb121.com ...SUCCESS
# nuoya.dxzrs.com ...SUCCESS
# taiwan01.taisnn.com ...FAIL
# down.ghjdfba.com ...FAIL
# tw.wppweb.com ...SUCCESS
# tg15.sejv888.com ...SUCCESS
# 103.193.243.225 ...FAIL
# www.swhyjys.com ...SUCCESS
# www.swhyjys.com ...SUCCESS
# down.959435.com ...SUCCESS
# xyl9388.top ...FAIL
# m.xyl9388.top ...FAIL
# www.uleiproex.com ...FAIL
# www.ctoh5.com ...FAIL
# www.bithumb77.com ...SUCCESS
# sly27.com ...SUCCESS
# h5.trade30868.xyz ...FAIL
# qqg.hiketang.cn ...SUCCESS
# www.yljtbc.com ...SUCCESS
# h5.etheru.xyz ...FAIL
# d.app70127.xyz ...FAIL
# xpj55787.com ...SUCCESS
# ara-celi.com ...FAIL
# bscoinvip.net ...FAIL
# www.30lv.xyz ...FAIL
# weo.zdahlu.com ...SUCCESS
# d.icetrad.xyz ...FAIL
# www.tauruss.top ...FAIL
# zhongan8.com ...SUCCESS
# www.o08.top ...SUCCESS
# en.avatrade.wiki ...FAIL
# download.bitfinex963.me ...SUCCESS
# crm.khhengton.com ...FAIL
# www.xmosa.vip ...FAIL
# down.chaojiqxz3.com ...SUCCESS
# 587657.com ...SUCCESS
# www.download678.com ...FAIL
# jlqldb.cn ...FAIL
# 154.213.18.187 ...FAIL
# fx-tradingscoins.com ...SUCCESS
# www.rjexpro.com ...FAIL
# www.dt32267.com ...FAIL
# www.mxjzcc.top ...FAIL
# d.gtmarketint.buzz ...FAIL
# down.ghjdfbb.com ...FAIL
# d.atfxint.buzz ...FAIL
# fxdd.zxdt.top ...FAIL
# www.bqbos.xyz ...FAIL
# d.app78627.xyz ...FAIL
# h5.trade56535.xyz ...FAIL
# qqwxi.org ...SUCCESS
# web.hjsa.xyz ...SUCCESS
# hncjagr.cn ...SUCCESS
# h5.hbtopglobal.com ...FAIL
# www.hitbtc168.com ...FAIL
# shxiaochuan.com ...FAIL
# orkunburun.com ...SUCCESS
# norwest.thegoodd.com ...SUCCESS
# qqwxe.org ...SUCCESS
# taiwan.dgm168.net ...FAIL
# jinsha.caiqiffssaa.com ...FAIL
# ol.oyooya.xyz ...SUCCESS
# app.zuonianli.com ...FAIL
# down.ghjdfbh.com ...SUCCESS
# zz.wbyqygl.com ...SUCCESS
# 8618199.com ...SUCCESS
# d.app87307.xyz ...FAIL
# d.app99068.xyz ...FAIL
# ff.fenfa-24.cn ...SUCCESS
# hashex.net ...FAIL
# d.bcointd.buzz ...FAIL
# h5.capital155.com ...FAIL
# download.longwanggj.com ...FAIL
# www.mommkn.org ...SUCCESS
# h5.trade08515.xyz ...FAIL
# www.kaykonw.cn ...SUCCESS
# lwxywm.com ...FAIL
# www.nncos.vip ...SUCCESS
# down.duan88a.com ...SUCCESS
# zygja.mnktrk.shop ...SUCCESS
# d.app87507.xyz ...FAIL
# down.gateswp.com ...SUCCESS
# www.dpom-global.com ...SUCCESS
# ios.fangjiajia.vip ...SUCCESS
# ios.paybf.shop ...SUCCESS
# m.wnsr4168.com ...FAIL
# zb3.sevenchat.shop ...SUCCESS
# ff.fxs6699.com ...SUCCESS
# www.eminios.vip ...FAIL
# qqwxd.net ...SUCCESS
# ubstest-ex.com ...SUCCESS
# btc.xm888.com ...FAIL
# vrbxdv.dtrex88.com ...SUCCESS
# d.nyseuronex.buzz ...FAIL
# hj32.xyz ...SUCCESS
# wap.zhiyinglianghua.com ...FAIL
# fabcons.cn ...SUCCESS
# m.okpro.vip ...SUCCESS
# www.coinonels.com ...SUCCESS
# itestfilght.com ...SUCCESS
# www.vestleglobal.com ...FAIL
# d.vestleglobal.buzz ...FAIL
# www.ac3t41ct9.com ...SUCCESS
# www.hkbite.com ...FAIL
# fc0712.com ...SUCCESS
# btcturopro.com ...SUCCESS
# 0430.gs1391.cc ...SUCCESS
# appdiyan8.cn ...FAIL
# h5.luwtrad.com ...FAIL
# h5.ejjsg.com ...SUCCESS
# d.app58001.xyz ...FAIL
# mm.wns469.net.cn ...FAIL
# down.sign233.com ...SUCCESS
# www.acycointrading.com ...FAIL
# ip896547m.top ...FAIL
# d.vestleprbil.com ...FAIL
# h5.capital221.com ...FAIL
# d.koorbitinra.com ...FAIL
# hd95s.fanrongchangsheng.com ...FAIL
# www.bitete.cc ...FAIL
# m.wns4168.com ...SUCCESS
# d.app65618.xyz ...SUCCESS
# www.bitcoinpro.vip ...SUCCESS
# m.mgm66998.com ...FAIL
# spe2npzh5e-www.oneclickblockchain.com ...FAIL
# ambrose.syins8.com ...SUCCESS
# www.gtmarketluy.com ...FAIL
# web.dongsenyule.com ...SUCCESS
# bairradafx.com ...FAIL
# www.lionmaxfx.com ...FAIL
# maxfx.com ...SUCCESS
# www.yh1316.com ...FAIL
# www.ordersforex.com ...SUCCESS
# www.springinforex.com ...SUCCESS
# springmt5.com ...SUCCESS
# . ...FAIL
# d.sixtrad.buzz ...FAIL
# web.spe29.com ...FAIL
# www.trony.live ...FAIL
# ff.bm30fkx.cn ...SUCCESS
# down.bstast.net ...SUCCESS
# tmxotc.com ...SUCCESS
# fir.testflighting.com ...SUCCESS
# www.bintrad.xyz ...FAIL
# www.lianruitrad.com ...FAIL
# buuy911.com ...FAIL
# only.yxwcua.shop ...SUCCESS
# only.leswl.cn ...FAIL
# only.app.pgxjlg.bar ...FAIL
# bolibs.com ...SUCCESS
# down.959435.com ...SUCCESS
# app.fimco.cn ...SUCCESS
# d.app83389.xyz ...FAIL
# btcqwea.com ...SUCCESS
# btczkk.com ...SUCCESS
# jisstykemrllo.com ...FAIL
# www.coinmamaglb.com ...FAIL
# h5.cap3721.com ...FAIL
# www.vestlepra.com ...FAIL
# www.eonmir.cc ...FAIL
# d.bitfinexfy.xyz ...FAIL
# ff.yjypmall.cn ...SUCCESS
# ff.yiypmall.cn ...FAIL
# h5.boersefrankglb.com ...FAIL
# www.btccoins1.xyz ...SUCCESS
# h5.cap-base.com ...FAIL
# www.avatradebl.com ...FAIL
# www.bmoglbr.com ...FAIL
# www.boersefrankglb.com ...FAIL
# www.eurextrade.xyz ...FAIL
# www.fpmarketsa.com ...FAIL
# www.kickexabr.com ...FAIL
# www.kingtellerfy.com ...FAIL
# www.koorbitglb.com ...FAIL
# www.lmbtrad.com ...FAIL
# www.usvaciu.com ...FAIL
# www.anliantd.com ...FAIL
# www.bioneas.com ...FAIL
# www.bitsovp.com ...FAIL
# www.cbixbenxal.com ...FAIL
# www.cxmtradft.com ...FAIL
# www.deutscheint.com ...FAIL
# www.easttd.com ...FAIL
# www.eightcapbl.com ...FAIL
# www.fortisglb.com ...FAIL
# www.fxcmral.com ...FAIL
# www.huntinglobal.com ...FAIL
# www.lmaxau.com ...FAIL
# www.luckyfortunev.com ...FAIL
# www.ncbcc.xyz ...FAIL
# www.orientaurora.xyz ...FAIL
# www.panteratd.com ...FAIL
# www.unijy.com ...FAIL
# giqqhwgdq.bnkas.net ...SUCCESS
# www.3405522.com ...SUCCESS
# spp6c8jale-www.anewwayoffriday.com ...SUCCESS
# mzh.wnnbpr.cn ...SUCCESS
# www.bensonweb68.com ...FAIL
# www.bldhk-fx.com ...FAIL
# d.krakenfly.xyz ...FAIL
# h5.trade31213.xyz ...FAIL
# yy.js-czhb.com ...SUCCESS
# h5.trade37119.xyz ...FAIL
# s.77fts.com ...SUCCESS
# www.trade93220.xyz ...FAIL
# down.959435.com ...SUCCESS
# www.exdboss.vip ...FAIL
# www.iosadboss.vip ...FAIL
# www.dbosscoin.com ...FAIL
# www.zrg5ljz.cn ...FAIL
# h5.trade13239.xyz ...FAIL
# zlgcdn.online ...FAIL
# www.tgferz.cloud ...FAIL
# h5.trade56181.xyz ...FAIL
# h5.trade21739.xyz ...FAIL
# nk02.diecg.com ...FAIL
# m.gsexpro.vip ...FAIL
# www.mitcsx.com ...SUCCESS
# www.yunnanyitianyun.com ...SUCCESS
# waps.jinhgold.com ...FAIL
# d.gdacvipa.buzz ...SUCCESS
# m.lamxpro.com ...FAIL
# m.ebcbitex.vip ...FAIL
# h5.trade73922.xyz ...FAIL
# app.dongzhenggp.com ...SUCCESS
# m.fxcm-cg.com ...FAIL
# d.app26526.xyz ...FAIL
# d.krakencla.com ...SUCCESS
# rs636.gs1491.cc ...SUCCESS
# yomanic2c.xyz ...FAIL
# sam168168.bftwtcbcc.com ...SUCCESS
# wm.jd3333.xyz ...FAIL
# www.8aabbaa.com ...FAIL
# wap.megamwap.vip ...FAIL
# asx.global-trademax.net ...SUCCESS
# huarunkijxsef.top ...FAIL
# 8989.350524.cn ...FAIL
# www.elvannyou.com ...FAIL
# select-global.com ...FAIL
# wwwy.sdpyion.com ...FAIL
# lazada8lzz-www.xhxmxz.com ...SUCCESS
# mizuho.hicoinapp.com ...SUCCESS
# www.tmgmom.com ...SUCCESS
# www.dwystudio.com ...SUCCESS
# engxin22.com ...FAIL
# d.app10581.xyz ...SUCCESS
# xinlian.xyz ...FAIL
# atm51688.siiua.com ...FAIL
# d.gdacvipa.xyz ...FAIL
# d.z2.wtf ...FAIL
# futureasset.net ...SUCCESS
# yw.gomncyo.cn ...SUCCESS
# spp6me7kzzs-www.anewwayoffriday.com ...SUCCESS
# m.ftmbitex.com ...FAIL
# coincheck.vip ...SUCCESS
# www.lb999.xyz ...SUCCESS
# wap.nasdaqwind.com ...SUCCESS
# www.zbgsel.buzz ...SUCCESS
# www.exchain3186.com ...SUCCESS
# hippo82edn-www.st-startube.com ...FAIL
# web.hippo828.com ...SUCCESS
# www.tfcvcoin.com ...SUCCESS
# www.telebitex.com ...FAIL
# 88678956.jsgj011.top ...SUCCESS
# www.m98xhabba.vip ...FAIL
# itestfilght.com ...SUCCESS
# ci.ls-bit.com ...SUCCESS
# www.redeflag.com ...FAIL
# etherpro.top ...SUCCESS
# aaaa1gy6hw-www.banyoudao.com ...FAIL
# spp6me7kzzs-www.anewwayoffriday.com ...SUCCESS
# www.go-dcep.com ...SUCCESS
# nl66sv1.cn ...FAIL
# www.huosuqian5555.top ...FAIL
# d.pfidcflu.buzz ...SUCCESS
# by6hwz.hfh9988.com ...SUCCESS
# www.agiobaiv.com ...FAIL
# app.droprich.co ...FAIL
# www.charsin.com ...FAIL
# www.cyntc.com ...SUCCESS
# www.bitoex.org ...FAIL
# ndunq.bxwrt.com ...SUCCESS
# shopmot.com ...SUCCESS
# h5.cap-well.xyz ...FAIL
# h5.trade86899.top ...SUCCESS
# download.anyingouji.com ...FAIL
# forppea.penaker.com ...FAIL
# b05.jhgcsp.com ...SUCCESS
# www.linkvcex.com ...FAIL
# www.aexonline.com ...FAIL
# qing889.ctnint.net ...FAIL
# www.ruxc.com ...SUCCESS
# h5.myrtlesau.com ...FAIL
# h5.minecoin.com ...FAIL
# herm9nt2fa-www.cov-aid.com ...FAIL
# m.wns.gh5685.cn ...FAIL
# www.duo-shou.cn ...SUCCESS
# webebcbit.net ...FAIL
# www.fartrode.vip ...SUCCESS
# thcftw-vip.com ...SUCCESS
# orpbj.ygxw18.website ...FAIL
# mebcbit.net ...FAIL
# www.eightcapau.com ...FAIL
# saxopro.leiyupingce.cn ...FAIL
# d.app91576.top ...FAIL
# www.dxdpro.vip ...FAIL
# trw8wh2lcz-www.5gflare.com ...SUCCESS
# www.64117.online ...FAIL
# d.becexgbly.xyz ...FAIL
# m.y95889.com ...SUCCESS
# www.zebpayex.co ...FAIL
# www.coinchecksexvip.xyz ...FAIL
# gfcs665.com ...SUCCESS
# www.fxcmfly.com ...SUCCESS
# www.ligousu.com ...FAIL
# user.greenstans.com ...FAIL
# trade.ircatital-tw.com ...FAIL
# hk.kpcbtw.com ...FAIL
# birginmary.msbrandong.com ...FAIL
# m.mgm188.cc ...FAIL
# ch6666.cc ...FAIL
# itestfilght.com ...SUCCESS
# www.coinpros2.xyz ...FAIL
# www.ad5599.cn ...SUCCESS
# m.aomahjs.com ...FAIL
# ww2.kjmxoxf.cn ...FAIL
# ceqznswbku.xyz ...FAIL
# www.zyewjhagns.xyz ...FAIL
# fxtmeu.com ...SUCCESS
# www.qa2365.cn ...SUCCESS
# m.lmcf.vip ...FAIL
# down.yyqqv.com ...SUCCESS
# www.zhonxinjr.cn ...SUCCESS
# 7yg.7kzyw.cn ...SUCCESS
# d.lamresearchly.buzz ...FAIL
# momanow.xyz ...FAIL
# www.eosglobalinvesting.com ...SUCCESS
# www.asibaweb.com ...FAIL
# www.nbty35.com ...SUCCESS
# www.323122.com ...FAIL
# 3018.shibo297.com ...SUCCESS
# www.huanqiu147.com ...FAIL
# www.183283.com ...FAIL
# m.huobo886.com ...FAIL
# r8ty1079.com ...FAIL
# ext01.icejp.net ...SUCCESS
# www.stonextw.com ...SUCCESS
# ggtrade008.xyz ...SUCCESS
# h5.trade53971.top ...FAIL
# bnmcvbn.sfddgf.com ...SUCCESS
# www.ghkm.bet ...FAIL
# d.fexglobag.buzz ...FAIL
# wap.yomanidctc.space ...FAIL
# d.app32103.top ...SUCCESS
# empire-earnings.com ...FAIL
# trustventure.com ...FAIL
# www.banyoudao.com ...FAIL
# www.anivoasia.com ...SUCCESS

# %% [raw]
# x = PingSite('www.passiveoutcomes.com')
# x

# %% [raw]
# len(x)

# %% [raw]
# !nslookup down.a51fan.com:8146/f1bu.app

# %%
df.loc[6]
# Out:
# Address              [103.127.125.151]
# Domain     https://www.bittrex168.com/
# Alias                              NaN
# Name              [www.bittrex168.com]
# Name: 6, dtype: object

# %%
print(df.shape)
df.to_csv('ScamIPs.csv',index=False)
# Out:
# (1085, 4)

# %%
list(df)
# Out:
# ['Address', 'Domain', 'Alias', 'Name']

# %%
domainIPs = pd.unique(df['Address'].astype('string'))
ipCount = {}

for IP in df['Address'].astype('string'):
    ipCount[IP] = ipCount.get(IP,0) + 1

# %%
sortedKeys = sorted(ipCount,key=lambda x:ipCount[x],reverse=True)
sortedKeys = [x for x in sortedKeys if ipCount[x] > 1]
print([ipCount[x] for x in sortedKeys])
# Out:
# [31, 22, 15, 12, 12, 11, 9, 9, 9, 9, 8, 8, 7, 7, 7, 7, 6, 6, 6, 6, 5, 5, 5, 5, 5, 5, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]

# %%
mostCommon = pd.DataFrame()

for key in sortedKeys[1:]:
    temp = df[df['Address'].astype('string') == key]
    
    mostCommon = mostCommon.append(temp)

# %%
mostCommon
# Out:
#                                                 Address  \
# 229                                       [34.98.99.30]
# 230                                       [34.98.99.30]
# 231                                       [34.98.99.30]
# 233                                       [34.98.99.30]
# 234                                       [34.98.99.30]
# ...                                                 ...
# 924                                     [18.162.229.81]
# 904   [154.198.217.75, 154.198.217.76, 154.198.217.7...
# 908   [154.198.217.75, 154.198.217.76, 154.198.217.7...
# 1073                                     [159.138.22.8]
# 1075                                     [159.138.22.8]
#
#                                         Domain  \
# 229                        http://igmarke.com/
# 230                      https://www.leta.ink/
# 231                  https://www.exblkpro.com/
# 233                     http://www.uh-und.com/
# 234                 https://www.bitlbxpro.com/
# ...                                        ...
# 924               https://www.newbnexusdt.com/
# 904   https://www.zaibuxingjiuchiji.com/atve29
# 908   https://www.zaibuxingjiuchiji.com/jvwaes
# 1073               http://www.323122.com:8930/
# 1075               http://www.183283.com:8930/
#
#                                                  Alias  \
# 229                                                NaN
# 230                                     [www.leta.ink]
# 231                                 [www.exblkpro.com]
# 233                                                NaN
# 234                                [www.bitlbxpro.com]
# ...                                                ...
# 924                                                NaN
# 904   [www.zaibuxingjiuchiji.com, g9t2mpvx.mfycdn.com]
# 908   [www.zaibuxingjiuchiji.com, g9t2mpvx.mfycdn.com]
# 1073                                               NaN
# 1075                                               NaN
#
#                          Name
# 229             [igmarke.com]
# 230                [leta.ink]
# 231            [exblkpro.com]
# 233          [www.uh-und.com]
# 234           [bitlbxpro.com]
# ...                       ...
# 924     [www.newbnexusdt.com]
# 904   [xcsnmh6d.n.mfycdn.com]
# 908   [xcsnmh6d.n.mfycdn.com]
# 1073         [www.323122.com]
# 1075         [www.183283.com]
#
# [355 rows x 4 columns]

# %%
mostCommon.to_csv('MostCommonIPs.csv', index=False)

# %% [markdown]
# # Get IPs

# %%
import requests
import json
import time

# %%
pingIPs = pd.read_csv("ScamIPs.csv")
pingIPs.shape
# Out:
# (1085, 4)

# %%
baseurl = 'http://ip-api.com/json/'

# %%
header = ['status',
 'country',
 'countryCode',
 'region',
 'regionName',
 'city',
 'zip',
 'lat',
 'lon',
 'timezone',
 'isp',
 'org',
 'as',
 'query']

# %%
ipCache = []
ipdf = pd.DataFrame(columns = header)

# %%
for IP in pingIPs['Address']:
    for b in IP.split(','):
        address = b.strip("[]\t '")
            
        if address not in ipCache:
            results = requests.get(baseurl + address)
            text = json.loads(results.text)
            ipdf = ipdf.append(text, ignore_index = True)
            time.sleep(1)
            ipCache.append(address)
        else:
            continue

# %%
address
# Out:
# '104.21.1.190'

# %%
ipdf
# Out:
#        status        country countryCode region    regionName         city  \
# 0     success  United States          US     IL      Illinois      Chicago
# 1     success  United States          US     IL      Illinois      Chicago
# 2     success  United States          US     IL      Illinois      Chicago
# 3     success  United States          US     IL      Illinois      Chicago
# 4     success  United States          US     IL      Illinois      Chicago
# ...       ...            ...         ...    ...           ...          ...
# 1807  success      Hong Kong          HK    KKC  Kowloon City  Tsimshatsui
# 1808  success  United States          US     NJ    New Jersey       Newark
# 1809  success  United States          US     NJ    New Jersey       Newark
# 1810  success  United States          US     NJ    New Jersey       Newark
# 1811  success  United States          US     NJ    New Jersey       Newark
#
#         zip      lat       lon          timezone               isp  \
# 0     60666  41.8781  -87.6298   America/Chicago  Amazon.com, Inc.
# 1     60666  41.8781  -87.6298   America/Chicago  Amazon.com, Inc.
# 2     60666  41.8781  -87.6298   America/Chicago  Amazon.com, Inc.
# 3     60666  41.8781  -87.6298   America/Chicago  Amazon.com, Inc.
# 4     60666  41.8781  -87.6298   America/Chicago  Amazon.com, Inc.
# ...     ...      ...       ...               ...               ...
# 1807  96521  22.3014  114.1760    Asia/Hong_Kong    ServiceID-PQWE
# 1808  07175  40.7357  -74.1724  America/New_York  Cloudflare, Inc.
# 1809  07175  40.7357  -74.1724  America/New_York  Cloudflare, Inc.
# 1810  07175  40.7357  -74.1724  America/New_York  Cloudflare, Inc.
# 1811  07175  40.7357  -74.1724  America/New_York  Cloudflare, Inc.
#
#                           org                        as  \
# 0     AWS CloudFront (GLOBAL)  AS16509 Amazon.com, Inc.
# 1     AWS CloudFront (GLOBAL)  AS16509 Amazon.com, Inc.
# 2     AWS CloudFront (GLOBAL)  AS16509 Amazon.com, Inc.
# 3     AWS CloudFront (GLOBAL)  AS16509 Amazon.com, Inc.
# 4     AWS CloudFront (GLOBAL)  AS16509 Amazon.com, Inc.
# ...                       ...                       ...
# 1807   Kwaifong Group Limited   AS142403 YISU CLOUD LTD
# 1808         Cloudflare, Inc.  AS13335 Cloudflare, Inc.
# 1809         Cloudflare, Inc.  AS13335 Cloudflare, Inc.
# 1810         Cloudflare, Inc.  AS13335 Cloudflare, Inc.
# 1811         Cloudflare, Inc.  AS13335 Cloudflare, Inc.
#
#                                      query message
# 0     2600:9000:2026:1a00:b:e5f8:8100:93a1     NaN
# 1     2600:9000:2026:7200:b:e5f8:8100:93a1     NaN
# 2     2600:9000:2026:8a00:b:e5f8:8100:93a1     NaN
# 3     2600:9000:2026:c400:b:e5f8:8100:93a1     NaN
# 4     2600:9000:2026:d800:b:e5f8:8100:93a1     NaN
# ...                                    ...     ...
# 1807                       185.251.248.225     NaN
# 1808                          104.21.51.96     NaN
# 1809                        172.67.178.133     NaN
# 1810             2606:4700:3031::6815:3360     NaN
# 1811             2606:4700:3036::ac43:b285     NaN
#
# [1812 rows x 15 columns]

# %%
ipdf.to_csv("IPs.csv", index = False)

# %% [markdown]
# # Merge

# %%
merged = pd.DataFrame(columns = list(df) + header)
merged
# Out:
# Empty DataFrame
# Columns: [Address, Domain, Alias, Name, status, country, countryCode, region, regionName, city, zip, lat, lon, timezone, isp, org, as, query]
# Index: []

# %%
for i in range(df.shape[0]):
    mergedRow = {}
    
    ipList = df.loc[i]['Address']
    chosenIP = ipList[0]
    
    mergedRow.update(df.loc[i].to_dict())
    tempDict = ipdf[ipdf['query'] == chosenIP].to_dict()
    # get rid of the annoying dicts in tempDict
    for key in tempDict:
        subkeys = list(tempDict[key].keys())
        tempDict[key] = tempDict[key][subkeys[0]]
    
    mergedRow.update(tempDict)
    
    merged = merged.append(mergedRow, ignore_index = True)

# %%
merged
# Out:
#                                                 Address  \
# 0     [2600:9000:2026:1a00:b:e5f8:8100:93a1, 2600:90...
# 1     [2600:9000:2026:4800:5:3cb:bb40:93a1, 2600:900...
# 2                                        [99.83.191.53]
# 3                                        [99.83.191.53]
# 4                                       [103.61.31.121]
# ...                                                 ...
# 1080                                  [185.251.248.225]
# 1081  [104.18.8.188, 104.18.9.188, 2606:4700::6812:8...
# 1082        [13.75.113.56, 168.63.205.135, 20.40.89.58]
# 1083                         [45.32.70.82, 45.77.3.111]
# 1084  [104.21.51.96, 172.67.178.133, 2606:4700:3031:...
#
#                                                  Domain  \
# 0                                https://mgmmacau.live/
# 1                                  https://larcla.live/
# 2                 https://down.a51fan.com:8146/f1bu.app
# 3                 https://down.a51fan.com:8146/0ka5.app
# 4                               http://app.kkyyipa.com/
# ...                                                 ...
# 1080                        https://bnmcvbn.sfddgf.com/
# 1081                              https://www.ghkm.bet/
# 1082  https://d.fexglobag.buzz/?id=686c6cd5115a54082...
# 1083  https://d.app32103.top/?id=a08123dd8a75fc02fca...
# 1084                          http://www.anivoasia.com/
#
#                                                   Alias  \
# 0                                       [mgmmacau.live]
# 1                                         [larcla.live]
# 2         [down.a51fan.com, bvepfcmbdn.bigbackbone.com]
# 3         [down.a51fan.com, bvepfcmbdn.bigbackbone.com]
# 4         [app.kkyyipa.com, kwknasktdu.bigbackbone.com]
# ...                                                 ...
# 1080                                                NaN
# 1081  [www.ghkm.bet, www.ghkm.bet.ktr4db5j.edgejoint...
# 1082         [d.fexglobag.buzz, rjs2nvym-u.funnull.vip]
# 1083                                   [d.app32103.top]
# 1084                                                NaN
#
#                                                    Name   status  \
# 0                       [d25jau5ikwq32c.cloudfront.net]  success
# 1                       [d2sf2uvueylcz1.cloudfront.net]  success
# 2                           [bvepfcmbdn.ddos2naive.com]  success
# 3                           [bvepfcmbdn.ddos2naive.com]  success
# 4                           [kwknasktdu.ddos2naive.com]  success
# ...                                                 ...      ...
# 1080                               [bnmcvbn.sfddgf.com]  success
# 1081  [www.ghkm.bet.cloudflare.ktr4db5j.edgejoint.ne...  success
# 1082                        [bd9xv5hw.n.funnullv12.com]  success
# 1083                          [hc06-site-02.cdn-ng.net]  success
# 1084                                [www.anivoasia.com]  success
#
#             country countryCode region                    regionName  \
# 0     United States          US     IL                      Illinois
# 1     United States          US     IL                      Illinois
# 2     United States          US     WA                    Washington
# 3     United States          US     WA                    Washington
# 4         Hong Kong          HK    KSS                  Sham Shui Po
# ...             ...         ...    ...                           ...
# 1080      Hong Kong          HK    KKC                  Kowloon City
# 1081  United States          US     NJ                    New Jersey
# 1082      Hong Kong          HK    HCW  Central and Western District
# 1083  United States          US     CA                    California
# 1084  United States          US     NJ                    New Jersey
#
#                 city    zip      lat       lon             timezone  \
# 0            Chicago  60666  41.8781  -87.6298      America/Chicago
# 1            Chicago  60666  41.8781  -87.6298      America/Chicago
# 2            Seattle  98108  47.6229 -122.3370  America/Los_Angeles
# 3            Seattle  98108  47.6229 -122.3370  America/Los_Angeles
# 4     Cheung Sha Wan         22.3363  114.1580       Asia/Hong_Kong
# ...              ...    ...      ...       ...                  ...
# 1080     Tsimshatsui  96521  22.3014  114.1760       Asia/Hong_Kong
# 1081          Newark  07175  40.7357  -74.1724     America/New_York
# 1082       Hong Kong  96521  22.2670  114.1880       Asia/Hong_Kong
# 1083     Los Angeles  90012  34.0544 -118.2440  America/Los_Angeles
# 1084          Newark  07175  40.7357  -74.1724     America/New_York
#
#                         isp                               org  \
# 0          Amazon.com, Inc.           AWS CloudFront (GLOBAL)
# 1          Amazon.com, Inc.           AWS CloudFront (GLOBAL)
# 2          Amazon.com, Inc.   AWS Global Accelerator (GLOBAL)
# 3          Amazon.com, Inc.   AWS Global Accelerator (GLOBAL)
# 4      ULan Network Limited              ULan Network Limited
# ...                     ...                               ...
# 1080         ServiceID-PQWE            Kwaifong Group Limited
# 1081       Cloudflare, Inc.                  Cloudflare, Inc.
# 1082  Microsoft Corporation  Microsoft Azure Cloud (eastasia)
# 1083   The Constant Company               Vultr Holdings, LLC
# 1084       Cloudflare, Inc.                  Cloudflare, Inc.
#
#                                      as                                 query  \
# 0              AS16509 Amazon.com, Inc.  2600:9000:2026:1a00:b:e5f8:8100:93a1
# 1              AS16509 Amazon.com, Inc.   2600:9000:2026:4800:5:3cb:bb40:93a1
# 2              AS16509 Amazon.com, Inc.                          99.83.191.53
# 3              AS16509 Amazon.com, Inc.                          99.83.191.53
# 4                 AS40065 CNSERVERS LLC                         103.61.31.121
# ...                                 ...                                   ...
# 1080            AS142403 YISU CLOUD LTD                       185.251.248.225
# 1081           AS13335 Cloudflare, Inc.                          104.18.8.188
# 1082       AS8075 Microsoft Corporation                          13.75.113.56
# 1083  AS20473 The Constant Company, LLC                           45.32.70.82
# 1084           AS13335 Cloudflare, Inc.                          104.21.51.96
#
#      message
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 1080     NaN
# 1081     NaN
# 1082     NaN
# 1083     NaN
# 1084     NaN
#
# [1085 rows x 19 columns]

# %%
merged.to_csv('ScamIPs.csv', index = False)
